# %%
# !pwd
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
# Out:
# /content/drive/MyDrive/Github/sampledatafoodsales

# %%
# !wget https://www.contextures.com/SampleData.zip
# Out:
# --2022-09-12 00:58:09--  https://www.contextures.com/SampleData.zip
# Resolving www.contextures.com (www.contextures.com)... 34.94.142.247
# Connecting to www.contextures.com (www.contextures.com)|34.94.142.247|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 57647 (56K) [application/zip]
# Saving to: ‘SampleData.zip’
#
# SampleData.zip      100%[===================>]  56.30K  --.-KB/s    in 0.006s
#
# 2022-09-12 00:58:09 (9.00 MB/s) - ‘SampleData.zip’ saved [57647/57647]

# %%
# !mkdir zip_content

# %%
# !sudo apt-get install unzip
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# unzip is already the newest version (6.0-21ubuntu1.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 20 not upgraded.

# %%
# !unzip SampleData.zip -d /content/zip_content/
# Out:
# Archive:  SampleData.zip
#   inflating: /content/zip_content/SampleData.xlsx

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %cd zip_content/

df = pd.read_excel("SampleData.xlsx", sheet_name=None)
# Out:
# [Errno 2] No such file or directory: 'zip_content/'
# /content/drive/MyDrive/Github/sampledatafoodsales
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-87531e972a1e> in <module>
#       5 get_ipython().run_line_magic('cd', 'zip_content/')
#       6
# ----> 7 df = pd.read_excel("SampleData.xlsx", sheet_name=None)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df.keys()
# Out:
# dict_keys(['Instructions', 'SalesOrders', 'MyLinks'])

# %%
df['SalesOrders'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   OrderDate  43 non-null     datetime64[ns]
#  1   Region     43 non-null     object
#  2   Rep        43 non-null     object
#  3   Item       43 non-null     object
#  4   Units      43 non-null     int64
#  5   Unit Cost  43 non-null     float64
#  6   Total      43 non-null     float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 2.5+ KB

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/Github/
# %cd sampledatafoodsales
# %ls -l
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Github
# /content/drive/MyDrive/Github/sampledatafoodsales
# total 205
# -rw------- 1 root root  83418 Sep 12 03:22 Financial.xlsx
# -rw------- 1 root root 125836 Jul  3 20:10 sampledatafoodsales.xlsx

# %%
df = pd.read_excel("Financial.xlsx", sheet_name=None)

# %%
df['Sheet1'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Segment              700 non-null    object
#  1   Country              700 non-null    object
#  2   Product              700 non-null    object
#  3   Discount Band        700 non-null    object
#  4   Units Sold           700 non-null    float64
#  5   Manufacturing Price  700 non-null    int64
#  6   Sale Price           700 non-null    int64
#  7   Gross Sales          700 non-null    float64
#  8   Discounts            700 non-null    float64
#  9    Sales               700 non-null    float64
#  10  COGS                 700 non-null    float64
#  11  Profit               700 non-null    float64
#  12  Date                 700 non-null    datetime64[ns]
#  13  Month Number         700 non-null    int64
#  14  Month Name           700 non-null    object
# ...

# %%
df_1 = df['Sheet1']

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Segment              700 non-null    object
#  1   Country              700 non-null    object
#  2   Product              700 non-null    object
#  3   Discount Band        700 non-null    object
#  4   Units Sold           700 non-null    float64
#  5   Manufacturing Price  700 non-null    int64
#  6   Sale Price           700 non-null    int64
#  7   Gross Sales          700 non-null    float64
#  8   Discounts            700 non-null    float64
#  9    Sales               700 non-null    float64
#  10  COGS                 700 non-null    float64
#  11  Profit               700 non-null    float64
#  12  Date                 700 non-null    datetime64[ns]
#  13  Month Number         700 non-null    int64
#  14  Month Name           700 non-null    object
# ...

# %%
df_1
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera          None
# 1          Government                   Germany  Carretera          None
# 2           Midmarket                    France  Carretera          None
# 3           Midmarket                   Germany  Carretera          None
# 4           Midmarket                    Mexico  Carretera          None
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %%
d_filter = df_1['Country'] == 'Canada'

# %%
d_f_product =  (df_1['Country'] == 'Canada') & (df_1['Product'] == 'Montana')

# %%
df_1[d_f_product]
# Out:
#               Segment Country  Product Discount Band  Units Sold  \
# 7    Channel Partners  Canada  Montana          None      2518.0
# 11         Enterprise  Canada  Montana          None      2665.5
# 14         Enterprise  Canada  Montana          None       345.0
# 71         Government  Canada  Montana           Low      1830.0
# 183         Midmarket  Canada  Montana           Low      1967.0
# 185        Government  Canada  Montana           Low      2851.0
# 357        Government  Canada  Montana        Medium       488.0
# 365        Government  Canada  Montana        Medium       708.0
# 368    Small Business  Canada  Montana        Medium      1283.0
# 405    Small Business  Canada  Montana        Medium      3802.5
# 408  Channel Partners  Canada  Montana        Medium      2321.0
# 410        Government  Canada  Montana        Medium      1611.0
# 543        Government  Canada  Montana          High      2734.0
# ...

# %%
df_1[d_f_product]['Month Name'].value_counts()
# Out:
# October      4
# June         2
# September    2
# December     2
# July         1
# August       1
# March        1
# February     1
# April        1
# November     1
# January      1
# May          1
# Name: Month Name, dtype: int64

# %%
df_filter = df_1[d_filter]

# %%
df_filter['Product'].value_counts()
# Out:
# Paseo        42
# VTT          22
# Carretera    20
# Velo         20
# Montana      18
# Amarilla     18
# Name: Product, dtype: int64

# %%
cnt = df_1.groupby('Country')

# %%
cnt['Product'].value_counts()
# Out:
# Country                   Product
# Canada                    Paseo        42
#                           VTT          22
#                           Carretera    20
#                           Velo         20
#                           Amarilla     18
#                           Montana      18
# France                    Paseo        40
#                           VTT          22
#                           Velo         22
#                           Montana      20
#                           Amarilla     18
#                           Carretera    18
# Germany                   Paseo        40
#                           VTT          22
#                           Velo         22
#                           Carretera    20
#                           Amarilla     18
#                           Montana      18
# Mexico                    Paseo        40
#                           Velo         22
#                           Amarilla     20
# ...

# %%
df_1.iloc[14]
# Out:
# Segment                         Enterprise
# Country                             Canada
# Product                            Montana
# Discount Band                         None
# Units Sold                           345.0
# Manufacturing Price                      5
# Sale Price                             125
# Gross Sales                        43125.0
# Discounts                              0.0
#  Sales                             43125.0
# COGS                               41400.0
# Profit                              1725.0
# Date                   2013-10-01 00:00:00
# Month Number                            10
# Month Name                         October
# Year                                  2013
# Name: 14, dtype: object

# %%
df_1['Month Name'].value_counts()
# Out:
# October      140
# December     105
# June          70
# September     70
# November      70
# January       35
# March         35
# July          35
# August        35
# February      35
# April         35
# May           35
# Name: Month Name, dtype: int64

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Segment              700 non-null    object
#  1   Country              700 non-null    object
#  2   Product              700 non-null    object
#  3   Discount Band        700 non-null    object
#  4   Units Sold           700 non-null    float64
#  5   Manufacturing Price  700 non-null    int64
#  6   Sale Price           700 non-null    int64
#  7   Gross Sales          700 non-null    float64
#  8   Discounts            700 non-null    float64
#  9    Sales               700 non-null    float64
#  10  COGS                 700 non-null    float64
#  11  Profit               700 non-null    float64
#  12  Date                 700 non-null    datetime64[ns]
#  13  Month Number         700 non-null    int64
#  14  Month Name           700 non-null    object
# ...

# %%
df_1.sample(50)
# Out:
#               Segment                   Country    Product Discount Band  \
# 686        Enterprise  United States of America       Velo          High
# 91         Enterprise                    France        VTT           Low
# 30         Government                   Germany      Paseo          None
# 164        Enterprise                   Germany      Paseo           Low
# 286        Government  United States of America      Paseo        Medium
# 619        Government                    Canada      Paseo          High
# 387    Small Business                    Mexico       Velo        Medium
# 379        Government                    Mexico      Paseo        Medium
# 607         Midmarket                    Canada        VTT          High
# 696    Small Business                    Mexico   Amarilla          High
# 47         Enterprise                   Germany   Amarilla          None
# 196        Government  United States of America      Paseo           Low
# ...

# %%
df_1.index.names
# Out:
# FrozenList([None])

# %%
multi = df_1.set_index(['Segment','Product'])

# %%
multi.index.names
# Out:
# FrozenList(['Segment', 'Product'])

# %%
multi
# Out:
#                                              Country Discount Band  \
# Segment          Product
# Government       Carretera                    Canada          None
#                  Carretera                   Germany          None
# Midmarket        Carretera                    France          None
#                  Carretera                   Germany          None
#                  Carretera                    Mexico          None
# ...                                              ...           ...
# Small Business   Amarilla                     France          High
#                  Amarilla                     Mexico          High
# Government       Montana                      Mexico          High
#                  Paseo                        Canada          High
# Channel Partners VTT        United States of America          High
#
#                             Units Sold  Manufacturing Price  Sale Price  \
# Segment          Product
# ...
