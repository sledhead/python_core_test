# %%
from string import Template

# %%
customer_sales = [('bill',35.45),('seth',55.65),('mike',12.45),('mary',75.35)]

customer_total = Template('Here is $name total grocery bill: $total')

for single_c in customer_sales:
  print( customer_total.substitute( name = single_c[0], total=single_c[1]))
# Out:
# Here is bill total grocery bill: 35.45
# Here is seth total grocery bill: 55.65
# Here is mike total grocery bill: 12.45
# Here is mary total grocery bill: 75.35

# %%
new_customer_total = Template("Here is ${name}'s total grocery bill: $total")

for single_c in customer_sales:
  print( new_customer_total.substitute( name = single_c[0], total=single_c[1]))
# Out:
# Here is bill's total grocery bill: 35.45
# Here is seth's total grocery bill: 55.65
# Here is mike's total grocery bill: 12.45
# Here is mary's total grocery bill: 75.35

# %%
new_customer_total = Template("Here is ${name}'s total grocery bill: $total in dollars")

for single_c in customer_sales:
  print( new_customer_total.substitute( name = single_c[0], total=single_c[1]))
# Out:
# Here is bill's total grocery bill: 35.45 in dollars
# Here is seth's total grocery bill: 55.65 in dollars
# Here is mike's total grocery bill: 12.45 in dollars
# Here is mary's total grocery bill: 75.35 in dollars
