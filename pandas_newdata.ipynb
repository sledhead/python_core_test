# %%
# !mkdir new_data
# %cd new_data
# !pwd
# Out:
# /content/new_data
# /content/new_data

# %%
# !wget https://store.pangaea.de/Publications/IizumiT_2019/gdhy_v1.2_v1.3_20190128.zip
# Out:
# --2022-09-26 06:56:04--  https://store.pangaea.de/Publications/IizumiT_2019/gdhy_v1.2_v1.3_20190128.zip
# Resolving store.pangaea.de (store.pangaea.de)... 134.1.2.171
# Connecting to store.pangaea.de (store.pangaea.de)|134.1.2.171|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15989683 (15M) [application/zip]
# Saving to: ‘gdhy_v1.2_v1.3_20190128.zip’
#
# gdhy_v1.2_v1.3_2019 100%[===================>]  15.25M  11.2MB/s    in 1.4s
#
# 2022-09-26 06:56:06 (11.2 MB/s) - ‘gdhy_v1.2_v1.3_20190128.zip’ saved [15989683/15989683]

# %%
# !apt install unzip
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# unzip is already the newest version (6.0-21ubuntu1.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 20 not upgraded.

# %%
# !unzip gdhy.zip

# %%
# !wget https://apps.bea.gov/industry/xls/io-annual/Use_SUT_Framework_2007_2012_DET.xlsx
# Out:
# --2022-09-26 07:09:23--  https://apps.bea.gov/industry/xls/io-annual/Use_SUT_Framework_2007_2012_DET.xlsx
# Resolving apps.bea.gov (apps.bea.gov)... 192.149.12.17, 2610:20:3006:1::25
# Connecting to apps.bea.gov (apps.bea.gov)|192.149.12.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1467803 (1.4M) [application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]
# Saving to: ‘Use_SUT_Framework_2007_2012_DET.xlsx’
#
# Use_SUT_Framework_2 100%[===================>]   1.40M  --.-KB/s    in 0.1s
#
# 2022-09-26 07:09:23 (9.58 MB/s) - ‘Use_SUT_Framework_2007_2012_DET.xlsx’ saved [1467803/1467803]

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
df = pd.read_excel("test_sheet.xlsx", sheet_name=None)

# %%
df.keys()
# Out:
# dict_keys(['ReadMe ', 'NAICS Codes', '2007', '2012'])

# %%
df_1 = pd.read_excel("test_sheet.xlsx", sheet_name='2007')
df_1.head()
# Out:
#   The Use Table (Supply-Use Framework), 2007             Unnamed: 1  \
# 0                      [Millions of dollars]                    NaN
# 1                Bureau of Economic Analysis                    NaN
# 2                                        NaN                    NaN
# 3                     Commodities/Industries                    NaN
# 4                                       Code  Commodity Description
#
#         Unnamed: 2     Unnamed: 3                   Unnamed: 4  \
# 0              NaN            NaN                          NaN
# 1              NaN            NaN                          NaN
# 2              NaN            NaN                          NaN
# 3  Oilseed farming  Grain farming  Vegetable and melon farming
# 4           1111A0         1111B0                       111200
#
#                    Unnamed: 5  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3  Fruit and tree nut farming
# ...

# %%
# !wget https://apps.bea.gov/industry/Release/XLS/GDPxInd/GrossOutput.xlsx
# Out:
# --2022-09-26 07:14:43--  https://apps.bea.gov/industry/Release/XLS/GDPxInd/GrossOutput.xlsx
# Resolving apps.bea.gov (apps.bea.gov)... 192.149.12.17, 2610:20:3006:1::25
# Connecting to apps.bea.gov (apps.bea.gov)|192.149.12.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 414953 (405K) [application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]
# Saving to: ‘GrossOutput.xlsx’
#
# GrossOutput.xlsx    100%[===================>] 405.23K  --.-KB/s    in 0.1s
#
# 2022-09-26 07:14:43 (3.57 MB/s) - ‘GrossOutput.xlsx’ saved [414953/414953]

# %%
df_n = pd.read_excel("GrossOutput.xlsx", sheet_name=None)

# %%
df_n.keys()
# Out:
# dict_keys(['Contents', 'TGO101-A', 'TGO101-Q', 'TGO103-A', 'TGO103-Q', 'TGO104-A', 'TGO104-Q', 'TGO105-A', 'TGO105-Q', 'TGO106-A', 'TGO106-Q', 'TGO107-A', 'TGO107-Q'])

# %%
df_n = pd.read_excel("GrossOutput.xlsx", sheet_name='TGO101-A')
df_n

# %%
# !wget http://www.historia.se/VolumeICh10Wages1860_.xls
# Out:
# --2022-09-26 07:19:54--  http://www.historia.se/VolumeICh10Wages1860_.xls
# Resolving www.historia.se (www.historia.se)... 46.30.213.61, 2a02:2350:5:10a:80ef:e857:216c:ab34
# Connecting to www.historia.se (www.historia.se)|46.30.213.61|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 160768 (157K) [application/vnd.ms-excel]
# Saving to: ‘VolumeICh10Wages1860_.xls’
#
# VolumeICh10Wages186 100%[===================>] 157.00K   482KB/s    in 0.3s
#
# 2022-09-26 07:19:55 (482 KB/s) - ‘VolumeICh10Wages1860_.xls’ saved [160768/160768]

# %%
# !wget https://www.fhfa.gov/DataTools/Downloads/Documents/HPI/HPI_PO_monthly_hist.xls
# Out:
# --2022-09-26 07:28:05--  https://www.fhfa.gov/DataTools/Downloads/Documents/HPI/HPI_PO_monthly_hist.xls
# Resolving www.fhfa.gov (www.fhfa.gov)... 13.226.52.117, 13.226.52.73, 13.226.52.75, ...
# Connecting to www.fhfa.gov (www.fhfa.gov)|13.226.52.117|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 132608 (130K) [application/vnd.ms-excel]
# Saving to: ‘HPI_PO_monthly_hist.xls’
#
# HPI_PO_monthly_hist 100%[===================>] 129.50K  --.-KB/s    in 0.04s
#
# 2022-09-26 07:28:05 (2.86 MB/s) - ‘HPI_PO_monthly_hist.xls’ saved [132608/132608]

# %%
# !pip install xlrd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install --upgrade xlrd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 96 kB 2.8 MB/s
# ...
#   Attempting uninstall: xlrd
#     Found existing installation: xlrd 1.1.0
#     Uninstalling xlrd-1.1.0:
#       Successfully uninstalled xlrd-1.1.0
# ...

# %%
# %cd new_data
# !pwd
# Out:
# /content/new_data
# /content/new_data

# %%
df_n = pd.read_excel("HPI.xls", sheet_name=None)

# %%
df_n.keys()
# Out:
# dict_keys(['Downloadable--Series to91--FLAT'])

# %%
df_n = pd.read_excel("HPI.xls", sheet_name='Downloadable--Series to91--FLAT')

# %%
df_n
# Out:
#                                             Unnamed: 0  \
# 0    Monthly FHFA House Price Index® for Census Div...
# 1                                                  NaN
# 2                                                Month
# 3                                                  NaN
# 4                                  1991-01-01 00:00:00
# ..                                                 ...
# 377                                2022-02-01 00:00:00
# 378                                2022-03-01 00:00:00
# 379                                2022-04-01 00:00:00
# 380                                2022-05-01 00:00:00
# 381                                2022-06-01 00:00:00
#
#                     Unnamed: 1                Unnamed: 2  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2    East North Central\n(NSA)  East North Central\n(SA)
# 3                          NaN                       NaN
# ...

# %%
df_n.iloc[2]
# Out:
# Unnamed: 0                         Month
# Unnamed: 1     East North Central\n(NSA)
# Unnamed: 2      East North Central\n(SA)
# Unnamed: 3     East South Central\n(NSA)
# Unnamed: 4      East South Central\n(SA)
# Unnamed: 5        Middle Atlantic\n(NSA)
# Unnamed: 6         Middle Atlantic\n(SA)
# Unnamed: 7             Mountain\n\n(NSA)
# Unnamed: 8              Mountain\n\n(SA)
# Unnamed: 9          New England\n\n(NSA)
# Unnamed: 10          New England\n\n(SA)
# Unnamed: 11             Pacific\n\n(NSA)
# Unnamed: 12              Pacific\n\n(SA)
# Unnamed: 13        South Atlantic\n(NSA)
# Unnamed: 14         South Atlantic\n(SA)
# Unnamed: 15    West North Central\n(NSA)
# Unnamed: 16     West North Central\n(SA)
# Unnamed: 17    West South Central\n(NSA)
# Unnamed: 18     West South Central\n(SA)
# Unnamed: 19                 USA\n\n(NSA)
# Unnamed: 20                  USA\n\n(SA)
# Name: 2, dtype: object

# %%
columns = df_n.iloc[2]
df_new = df_n[4:]
df_new.columns = columns

# %%
df_new
# Out:
# 2                  Month East North Central\n(NSA) East North Central\n(SA)  \
# 4    1991-01-01 00:00:00                       100                      100
# 5    1991-02-01 00:00:00                    100.91                   100.97
# 6    1991-03-01 00:00:00                    101.31                   100.92
# 7    1991-04-01 00:00:00                     101.7                      101
# 8    1991-05-01 00:00:00                    102.33                   101.37
# ..                   ...                       ...                      ...
# 377  2022-02-01 00:00:00                    301.47                   302.92
# 378  2022-03-01 00:00:00                    307.95                   307.28
# 379  2022-04-01 00:00:00                    314.51                   311.02
# 380  2022-05-01 00:00:00                       321                    315.3
# 381  2022-06-01 00:00:00                    321.33                   314.15
#
# ...
