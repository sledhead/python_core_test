# %%
small_lst = [x *2 for x in range(1,15)]

small_dict = {key:val for (key,val) in enumerate(small_lst,1)}

print(small_dict)
# Out:
# {1: 2, 2: 4, 3: 6, 4: 8, 5: 10, 6: 12, 7: 14, 8: 16, 9: 18, 10: 20, 11: 22, 12: 24, 13: 26, 14: 28}

# %%
print("this is pretty")
# Out:
# this is pretty

# %%
#looking at dict compresion
input = ['Duration', 'F0', 'F1', 'F2', 'F3']
output = {'Duration': 0, 'F0': 1, 'F1': 2, 'F2': 3, 'F3': 4}

right_output = {key:val for (key,val) in enumerate(input,0)}

print(right_output)

back_output = {val:key for (key,val) in enumerate(input,0)}

print(back_output)
# Out:
# {0: 'Duration', 1: 'F0', 2: 'F1', 3: 'F2', 4: 'F3'}
# {'Duration': 0, 'F0': 1, 'F1': 2, 'F2': 3, 'F3': 4}
