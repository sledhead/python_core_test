# %%
import pandas as pd
import numpy as np
df = pd.DataFrame.from_dict({
    'Name': ['Nik', 'Kate', 'Evan', 'Kyra', np.NaN],
    'Age': [33, 32, 40, 57, np.NaN],
    'Location': ['Toronto', 'London', 'New York', np.NaN, np.NaN]
})

# %%
print(df)
# Out:
#    Name   Age  Location
# 0   Nik  33.0   Toronto
# 1  Kate  32.0    London
# 2  Evan  40.0  New York
# 3  Kyra  57.0       NaN
# 4   NaN   NaN       NaN

# %%
print(df.isnull())
# Out:
#     Name    Age  Location
# 0  False  False     False
# 1  False  False     False
# 2  False  False     False
# 3  False  False      True
# 4   True   True      True

# %%
print(df.isnull().sum())
# Out:
# Name        1
# Age         1
# Location    2
# dtype: int64

# %%
df_drop = df.dropna()

# %%
print(df_drop)
# Out:
#    Name   Age  Location
# 0   Nik  33.0   Toronto
# 1  Kate  32.0    London
# 2  Evan  40.0  New York

# %%
df.fillna(0)
# Out:
#    Name   Age  Location
# 0   Nik  33.0   Toronto
# 1  Kate  32.0    London
# 2  Evan  40.0  New York
# 3  Kyra  57.0         0
# 4     0   0.0         0

# %%
df.fillna({'Name':'Someone','Age':25,'Location':'USA'})
# Out:
#       Name   Age  Location
# 0      Nik  33.0   Toronto
# 1     Kate  32.0    London
# 2     Evan  40.0  New York
# 3     Kyra  57.0       USA
# 4  Someone  25.0       USA

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df
# Out:
#    Name   Age  Location
# 0   Nik  33.0   Toronto
# 1  Kate  32.0    London
# 2  Evan  40.0  New York
# 3  Kyra  57.0       NaN
# 4   NaN  40.5       NaN
