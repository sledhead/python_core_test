# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/Github/
# %cd sampledatafoodsales
# %ls -a

import numpy as np
import pandas as pd
from pandas import Series, DataFrame

df = pd.read_excel("sampledatafoodsales.xlsx", sheet_name="FoodSales")
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Github
# /content/drive/MyDrive/Github/sampledatafoodsales
# sampledatafoodsales.xlsx

# %%
df
# Out:
#      OrderDate Region         City  Category         Product  Quantity  \
# 0   2020-01-01   East       Boston      Bars          Carrot      33.0
# 1   2020-01-04   East       Boston  Crackers     Whole Wheat      87.0
# 2   2020-01-07   West  Los Angeles   Cookies  Chocolate Chip      58.0
# 3   2020-01-10   East     New York   Cookies  Chocolate Chip      82.0
# 4   2020-01-13   East       Boston   Cookies       Arrowroot      38.0
# ..         ...    ...          ...       ...             ...       ...
# 239 2021-12-18   East       Boston   Cookies       Arrowroot      34.0
# 240 2021-12-21   East       Boston   Cookies  Chocolate Chip     245.0
# 241 2021-12-24   East       Boston  Crackers     Whole Wheat      30.0
# 242 2021-12-27   West  Los Angeles      Bars            Bran      30.0
# 243 2021-12-30   West  Los Angeles   Cookies  Oatmeal Raisin      44.0
#
#      UnitPrice  TotalPrice
# 0         1.77       58.41
# 1         3.49      303.63
# 2         1.87      108.46
# ...

# %%
df.sort_values(by='Product')
# Out:
#      OrderDate Region         City  Category      Product  Quantity  \
# 121 2020-12-30   West    San Diego   Cookies    Arrowroot      83.0
# 191 2021-07-27   West  Los Angeles   Cookies    Arrowroot      20.0
# 185 2021-07-09   East     New York   Cookies    Arrowroot      37.0
# 171 2021-05-28   West    San Diego   Cookies    Arrowroot      36.0
# 48  2020-05-25   East       Boston   Cookies    Arrowroot      27.0
# ..         ...    ...          ...       ...          ...       ...
# 50  2020-05-31   East       Boston  Crackers  Whole Wheat      33.0
# 56  2020-06-18   East       Boston  Crackers  Whole Wheat      38.0
# 54  2020-06-12   West    San Diego  Crackers  Whole Wheat      20.0
# 78  2020-08-23   East       Boston  Crackers  Whole Wheat      21.0
# 97  2020-10-19   East     New York  Crackers  Whole Wheat      32.0
#
#      UnitPrice  TotalPrice
# 121       2.18      180.94
# 191       2.18       43.60
# 185       2.18       80.66
# 171       2.18       78.48
# ...

# %%
df.sort_values(by=['Product', 'City'], inplace=True)

# %%
df
# Out:
#      OrderDate Region       City  Category      Product  Quantity  UnitPrice  \
# 4   2020-01-13   East     Boston   Cookies    Arrowroot      38.0       2.18
# 10  2020-01-31   East     Boston   Cookies    Arrowroot      36.0       2.18
# 16  2020-02-18   East     Boston   Cookies    Arrowroot      43.0       2.18
# 48  2020-05-25   East     Boston   Cookies    Arrowroot      27.0       2.18
# 76  2020-08-17   East     Boston   Cookies    Arrowroot      31.0       2.18
# ..         ...    ...        ...       ...          ...       ...        ...
# 97  2020-10-19   East   New York  Crackers  Whole Wheat      32.0       3.49
# 128 2021-01-20   East   New York  Crackers  Whole Wheat      31.0       3.49
# 237 2021-12-12   East   New York  Crackers  Whole Wheat      25.0       3.49
# 54  2020-06-12   West  San Diego  Crackers  Whole Wheat      20.0       3.49
# 62  2020-07-06   West  San Diego  Crackers  Whole Wheat      28.0       3.49
#
#      TotalPrice
# 4         82.84
# ...

# %%
df.sort_index(inplace=True)

# %%
df
# Out:
#      OrderDate Region         City  Category         Product  Quantity  \
# 0   2020-01-01   East       Boston      Bars          Carrot      33.0
# 1   2020-01-04   East       Boston  Crackers     Whole Wheat      87.0
# 2   2020-01-07   West  Los Angeles   Cookies  Chocolate Chip      58.0
# 3   2020-01-10   East     New York   Cookies  Chocolate Chip      82.0
# 4   2020-01-13   East       Boston   Cookies       Arrowroot      38.0
# ..         ...    ...          ...       ...             ...       ...
# 239 2021-12-18   East       Boston   Cookies       Arrowroot      34.0
# 240 2021-12-21   East       Boston   Cookies  Chocolate Chip     245.0
# 241 2021-12-24   East       Boston  Crackers     Whole Wheat      30.0
# 242 2021-12-27   West  Los Angeles      Bars            Bran      30.0
# 243 2021-12-30   West  Los Angeles   Cookies  Oatmeal Raisin      44.0
#
#      UnitPrice  TotalPrice
# 0         1.77       58.41
# 1         3.49      303.63
# 2         1.87      108.46
# ...

# %%
df.sort_values(by=['City','UnitPrice'], ascending=[True,False])
# Out:
#      OrderDate Region       City  Category       Product  Quantity  UnitPrice  \
# 50  2020-05-31   East     Boston  Crackers   Whole Wheat      33.0       3.49
# 56  2020-06-18   East     Boston  Crackers   Whole Wheat      38.0       3.49
# 64  2020-07-12   East     Boston  Crackers   Whole Wheat      42.0       3.49
# 78  2020-08-23   East     Boston  Crackers   Whole Wheat      21.0       3.49
# 92  2020-10-04   East     Boston  Crackers   Whole Wheat      38.0       3.49
# ..         ...    ...        ...       ...           ...       ...        ...
# 179 2021-06-21   West  San Diego      Bars        Carrot      41.0       1.77
# 201 2021-08-26   West  San Diego      Bars        Carrot      41.0       1.77
# 34  2020-04-13   West  San Diego    Snacks  Potato Chips      28.0       1.68
# 69  2020-07-27   West  San Diego    Snacks  Potato Chips      31.0       1.68
# 145 2021-03-11   West  San Diego    Snacks  Potato Chips      41.0       1.68
#
#      TotalPrice
# ...

# %%
df['Quantity'].nlargest(10)
# Out:
# 57     306.0
# 51     288.0
# 240    245.0
# 119    237.0
# 141    232.0
# 95     224.0
# 232    211.0
# 29     193.0
# 215    175.0
# 6      149.0
# Name: Quantity, dtype: float64

# %%
df.nlargest(10,columns='Quantity')
# Out:
#      OrderDate Region         City  Category         Product  Quantity  \
# 57  2020-06-21   West  Los Angeles      Bars          Carrot     306.0
# 51  2020-06-03   West  Los Angeles   Cookies  Oatmeal Raisin     288.0
# 240 2021-12-21   East       Boston   Cookies  Chocolate Chip     245.0
# 119 2020-12-24   East     New York   Cookies       Arrowroot     237.0
# 141 2021-02-28   West  Los Angeles   Cookies  Chocolate Chip     232.0
# 95  2020-10-13   East     New York   Cookies       Arrowroot     224.0
# 232 2021-11-27   East       Boston   Cookies  Chocolate Chip     211.0
# 29  2020-03-29   East       Boston   Cookies  Oatmeal Raisin     193.0
# 215 2021-10-07   East     New York   Cookies       Arrowroot     175.0
# 6   2020-01-19   East       Boston  Crackers     Whole Wheat     149.0
#
#      UnitPrice  TotalPrice
# 57        1.77      541.62
# 51        2.84      817.92
# 240       1.87      458.15
# 119       2.18      516.66
# 141       1.87      433.84
# ...

# %%
df.nsmallest(10,columns='Quantity')
# Out:
#      OrderDate Region         City  Category       Product  Quantity  \
# 37  2020-04-22   West  Los Angeles      Bars        Carrot      20.0
# 54  2020-06-12   West    San Diego  Crackers   Whole Wheat      20.0
# 98  2020-10-22   West    San Diego      Bars        Carrot      20.0
# 191 2021-07-27   West  Los Angeles   Cookies     Arrowroot      20.0
# 208 2021-09-16   East     New York    Snacks  Potato Chips      20.0
# 230 2021-11-21   West    San Diego      Bars        Carrot      20.0
# 233 2021-11-30   East       Boston  Crackers   Whole Wheat      20.0
# 44  2020-05-13   West  Los Angeles  Crackers   Whole Wheat      21.0
# 78  2020-08-23   East       Boston  Crackers   Whole Wheat      21.0
# 136 2021-02-13   East     New York    Snacks  Potato Chips      21.0
#
#      UnitPrice  TotalPrice
# 37        1.77       35.40
# 54        3.49       69.80
# 98        1.77       35.40
# 191       2.18       43.60
# 208       1.68       33.60
# 230       1.77       35.40
# ...

# %%
df['Quantity'].median()
# Out:
# 47.0

# %%
df.median()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Quantity       47.000
# UnitPrice       1.870
# TotalPrice    102.755
# dtype: float64

# %%
df.describe()
# Out:
#          Quantity   UnitPrice  TotalPrice
# count  244.000000  244.000000  244.000000
# mean    63.286885    2.200820  136.580246
# std     47.112505    0.600169  108.354231
# min     20.000000    1.350000   33.600000
# 25%     31.000000    1.770000   72.570000
# 50%     47.000000    1.870000  102.755000
# 75%     80.000000    2.840000  159.300000
# max    306.000000    3.490000  817.920000

# %%
df['City'].count()
# Out:
# 244

# %%
df
# Out:
#      OrderDate Region         City  Category         Product  Quantity  \
# 0   2020-01-01   East       Boston      Bars          Carrot      33.0
# 1   2020-01-04   East       Boston  Crackers     Whole Wheat      87.0
# 2   2020-01-07   West  Los Angeles   Cookies  Chocolate Chip      58.0
# 3   2020-01-10   East     New York   Cookies  Chocolate Chip      82.0
# 4   2020-01-13   East       Boston   Cookies       Arrowroot      38.0
# ..         ...    ...          ...       ...             ...       ...
# 239 2021-12-18   East       Boston   Cookies       Arrowroot      34.0
# 240 2021-12-21   East       Boston   Cookies  Chocolate Chip     245.0
# 241 2021-12-24   East       Boston  Crackers     Whole Wheat      30.0
# 242 2021-12-27   West  Los Angeles      Bars            Bran      30.0
# 243 2021-12-30   West  Los Angeles   Cookies  Oatmeal Raisin      44.0
#
#      UnitPrice  TotalPrice
# 0         1.77       58.41
# 1         3.49      303.63
# 2         1.87      108.46
# ...

# %%
df['Category'].value_counts()
# Out:
# Cookies     95
# Bars        94
# Snacks      29
# Crackers    26
# Name: Category, dtype: int64

# %%
df['Category'].value_counts(normalize=True)
# Out:
# Cookies     0.389344
# Bars        0.385246
# Snacks      0.118852
# Crackers    0.106557
# Name: Category, dtype: float64

# %%
category_grp = df.groupby(['Category'])

# %%
category_grp.get_group('Bars')
# Out:
#      OrderDate Region         City Category Product  Quantity  UnitPrice  \
# 0   2020-01-01   East       Boston     Bars  Carrot      33.0       1.77
# 5   2020-01-16   East       Boston     Bars  Carrot      54.0       1.77
# 7   2020-01-22   West  Los Angeles     Bars  Carrot      51.0       1.77
# 8   2020-01-25   East     New York     Bars  Carrot     100.0       1.77
# 13  2020-02-09   West  Los Angeles     Bars  Carrot      44.0       1.77
# ..         ...    ...          ...      ...     ...       ...        ...
# 227 2021-11-12   West  Los Angeles     Bars  Carrot     137.0       1.77
# 230 2021-11-21   West    San Diego     Bars  Carrot      20.0       1.77
# 234 2021-12-03   West  Los Angeles     Bars    Bran      42.0       1.87
# 236 2021-12-09   East     New York     Bars  Carrot      38.0       1.77
# 242 2021-12-27   West  Los Angeles     Bars    Bran      30.0       1.87
#
#      TotalPrice
# 0         58.41
# 5         95.58
# 7         90.27
# 8        177.00
# ...

# %%
category_grp['Product'].value_counts()
# Out:
# Category  Product
# Bars      Carrot            64
#           Bran              27
#           Banana             3
# Cookies   Chocolate Chip    33
#           Arrowroot         31
#           Oatmeal Raisin    31
# Crackers  Whole Wheat       26
# Snacks    Potato Chips      22
#           Pretzels           7
# Name: Product, dtype: int64

# %%
category_grp['Product'].value_counts().loc['Cookies']
# Out:
# Product
# Chocolate Chip    33
# Arrowroot         31
# Oatmeal Raisin    31
# Name: Product, dtype: int64

# %%
category_grp['Quantity'].median()
# Out:
# Category
# Bars        51.5
# Cookies     63.0
# Crackers    30.0
# Snacks      29.0
# Name: Quantity, dtype: float64

# %%
category_grp['UnitPrice'].median()
# Out:
# Category
# Bars        1.77
# Cookies     2.18
# Crackers    3.49
# Snacks      1.68
# Name: UnitPrice, dtype: float64

# %%
category_grp['UnitPrice'].agg(['median', 'mean'])
# Out:
#           median      mean
# Category
# Bars        1.77  1.814681
# Cookies     2.18  2.287684
# Crackers    3.49  3.490000
# Snacks      1.68  2.012069
