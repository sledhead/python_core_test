# %%
def add_me(x, y):

  return x + y

def times_me(x, y):

  return x * y


def cool_function(special_func, x, y):

  return special_func(x,y)


kk = cool_function(add_me,4,5)

print(kk)

mm = cool_function(times_me, 5, 6)

print(mm)
# Out:
# 9
# 30

# %%
#third test me

# %%
#the new one is here...

# %%
gg = [3,4,5,6]

# %%
#first class function
