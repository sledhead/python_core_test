# %%
from dataclasses import dataclass
import os

# %%
@dataclass
class Worker_Logging:
  log_file_name: str
  report_level: int

# %%
base_path = os.getcwd()

final_dest = os.path.join(base_path,'NewFolder')

print(final_dest)
print(type(base_path))
# Out:
# /content/NewFolder
# <class 'str'>
