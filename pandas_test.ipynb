# %%
import pandas as pd
import numpy as np

data_1 = {'product_1': ['computer','monitor','printer','desk'],
                   'price_1': [1200,800,200,350]
                   }
df1 = pd.DataFrame(data_1)


data_2 = {'product_2': ['computer','monitor','printer','desk'],
                    'price_2': [900,800,300,350]
                    }
df2 = pd.DataFrame(data_2)


df1['price_2'] = df2['price_2'] #add the price_2 column from df2 to df1
df1['prices_match'] = np.where(df1['price_1'] == df2['price_2'], 'True', 'False') #create a new column in df1 to check if prices match
df1['price_diff'] = np.where(df1['price_1'] == df2['price_2'], 0, df1['price_1'] - df2['price_2']) #create a new column in df1 for price diff

print(df1)
# Out:
#   product_1  price_1  price_2 prices_match  price_diff
# 0  computer     1200      900        False         300
# 1   monitor      800      800         True           0
# 2   printer      200      300        False        -100
# 3      desk      350      350         True           0

# %%
print(df1.equals(df2))
# Out:
# False

# %%
# creating and initializing a nested list
age_list = [['Afghanistan', 1952, 8425333, 'Asia'],
            ['Australia', 1957, 9712569, 'Oceania'],
            ['Brazil', 1962, 76039390, 'Americas'],
            ['China', 1957, 637408000, 'Asia'],
            ['France', 1957, 44310863, 'Europe'],
            ['India', 1952, 3.72e+08, 'Asia'],
            ['United States', 1957, 171984000, 'Americas']]
  
# creating a pandas dataframe
df = pd.DataFrame(age_list, columns=['Country', 'Year',
                                     'Population', 'Continent'])

print(df)
# Out:
#          Country  Year   Population Continent
# 0    Afghanistan  1952    8425333.0      Asia
# 1      Australia  1957    9712569.0   Oceania
# 2         Brazil  1962   76039390.0  Americas
# 3          China  1957  637408000.0      Asia
# 4         France  1957   44310863.0    Europe
# 5          India  1952  372000000.0      Asia
# 6  United States  1957  171984000.0  Americas

# %%
# Sorting by column "Population"
df.sort_values(by=['Population'], ascending=False)
# Out:
#          Country  Year   Population Continent
# 3          China  1957  637408000.0      Asia
# 5          India  1952  372000000.0      Asia
# 6  United States  1957  171984000.0  Americas
# 2         Brazil  1962   76039390.0  Americas
# 4         France  1957   44310863.0    Europe
# 1      Australia  1957    9712569.0   Oceania
# 0    Afghanistan  1952    8425333.0      Asia

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/JackyP/testing/master/datasets/nycflights.csv", usecols=range(1,17))

# %%
print(df.head())
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 0  2013      1    1     517.0        2.0     830.0       11.0      UA  N14228
# 1  2013      1    1     533.0        4.0     850.0       20.0      UA  N24211
# 2  2013      1    1     542.0        2.0     923.0       33.0      AA  N619AA
# 3  2013      1    1     544.0       -1.0    1004.0      -18.0      B6  N804JB
# 4  2013      1    1     554.0       -6.0     812.0      -25.0      DL  N668DN
#
#    flight origin dest  air_time  distance  hour  minute
# 0    1545    EWR  IAH     227.0      1400   5.0    17.0
# 1    1714    LGA  IAH     227.0      1416   5.0    33.0
# 2    1141    JFK  MIA     160.0      1089   5.0    42.0
# 3     725    JFK  BQN     183.0      1576   5.0    44.0
# 4     461    LGA  ATL     116.0       762   5.0    54.0

# %%
newdf = df[(df.origin == "JFK") & (df.carrier == "B6")]
print(newdf.head())
# Out:
#     year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 3   2013      1    1     544.0       -1.0    1004.0      -18.0      B6
# 8   2013      1    1     557.0       -3.0     838.0       -8.0      B6
# 10  2013      1    1     558.0       -2.0     849.0       -2.0      B6
# 11  2013      1    1     558.0       -2.0     853.0       -3.0      B6
# 15  2013      1    1     559.0        0.0     702.0       -4.0      B6
#
#    tailnum  flight origin dest  air_time  distance  hour  minute
# 3   N804JB     725    JFK  BQN     183.0      1576   5.0    44.0
# 8   N593JB      79    JFK  MCO     140.0       944   5.0    57.0
# 10  N793JB      49    JFK  PBI     149.0      1028   5.0    58.0
# 11  N657JB      71    JFK  TPA     158.0      1005   5.0    58.0
# 15  N708JB    1806    JFK  BOS      44.0       187   5.0    59.0

# %%
newdf = df.query('origin == "JFK" & carrier == "B6"')
print(newdf.head())
# Out:
#     year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 3   2013      1    1     544.0       -1.0    1004.0      -18.0      B6
# 8   2013      1    1     557.0       -3.0     838.0       -8.0      B6
# 10  2013      1    1     558.0       -2.0     849.0       -2.0      B6
# 11  2013      1    1     558.0       -2.0     853.0       -3.0      B6
# 15  2013      1    1     559.0        0.0     702.0       -4.0      B6
#
#    tailnum  flight origin dest  air_time  distance  hour  minute
# 3   N804JB     725    JFK  BQN     183.0      1576   5.0    44.0
# 8   N593JB      79    JFK  MCO     140.0       944   5.0    57.0
# 10  N793JB      49    JFK  PBI     149.0      1028   5.0    58.0
# 11  N657JB      71    JFK  TPA     158.0      1005   5.0    58.0
# 15  N708JB    1806    JFK  BOS      44.0       187   5.0    59.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Github/
# %cd sampledatafoodsales
# %ls -a
# Out:
# /content/drive/MyDrive/Github
# /content/drive/MyDrive/Github/sampledatafoodsales
# sampledatafoodsales.xlsx

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

df = pd.read_excel("sampledatafoodsales.xlsx", sheet_name="FoodSales")

# %%
df
# Out:
#      OrderDate Region         City  Category         Product  Quantity  \
# 0   2020-01-01   East       Boston      Bars          Carrot      33.0
# 1   2020-01-04   East       Boston  Crackers     Whole Wheat      87.0
# 2   2020-01-07   West  Los Angeles   Cookies  Chocolate Chip      58.0
# 3   2020-01-10   East     New York   Cookies  Chocolate Chip      82.0
# 4   2020-01-13   East       Boston   Cookies       Arrowroot      38.0
# ..         ...    ...          ...       ...             ...       ...
# 239 2021-12-18   East       Boston   Cookies       Arrowroot      34.0
# 240 2021-12-21   East       Boston   Cookies  Chocolate Chip     245.0
# 241 2021-12-24   East       Boston  Crackers     Whole Wheat      30.0
# 242 2021-12-27   West  Los Angeles      Bars            Bran      30.0
# 243 2021-12-30   West  Los Angeles   Cookies  Oatmeal Raisin      44.0
#
#      UnitPrice  TotalPrice
# 0         1.77       58.41
# 1         3.49      303.63
# 2         1.87      108.46
# ...

# %%
sp_filter = df['City'] == "Boston"

# %%
df[sp_filter]
# Out:
#      OrderDate Region    City  Category         Product  Quantity  UnitPrice  \
# 0   2020-01-01   East  Boston      Bars          Carrot      33.0       1.77
# 1   2020-01-04   East  Boston  Crackers     Whole Wheat      87.0       3.49
# 4   2020-01-13   East  Boston   Cookies       Arrowroot      38.0       2.18
# 5   2020-01-16   East  Boston      Bars          Carrot      54.0       1.77
# 6   2020-01-19   East  Boston  Crackers     Whole Wheat     149.0       3.49
# ..         ...    ...     ...       ...             ...       ...        ...
# 232 2021-11-27   East  Boston   Cookies  Chocolate Chip     211.0       1.87
# 233 2021-11-30   East  Boston  Crackers     Whole Wheat      20.0       3.49
# 239 2021-12-18   East  Boston   Cookies       Arrowroot      34.0       2.18
# 240 2021-12-21   East  Boston   Cookies  Chocolate Chip     245.0       1.87
# 241 2021-12-24   East  Boston  Crackers     Whole Wheat      30.0       3.49
#
#      TotalPrice
# 0         58.41
# ...

# %%
 df.loc[sp_filter,['Category','Product']]
# Out:
#      Category         Product
# 0        Bars          Carrot
# 1    Crackers     Whole Wheat
# 4     Cookies       Arrowroot
# 5        Bars          Carrot
# 6    Crackers     Whole Wheat
# ..        ...             ...
# 232   Cookies  Chocolate Chip
# 233  Crackers     Whole Wheat
# 239   Cookies       Arrowroot
# 240   Cookies  Chocolate Chip
# 241  Crackers     Whole Wheat
#
# [88 rows x 2 columns]

# %%
sp2_filter = (df['Category'] == 'Cookies') & (df['Quantity'] > 50) 

df_sp2 = df.loc[sp2_filter]

# %%
sp_cookies_pivot = df_sp2.pivot_table(index='City', columns='Product', values='TotalPrice', fill_value=0, aggfunc=['sum'])
sp_cookies_pivot
# Out:
#                   sum
# Product     Arrowroot Chocolate Chip Oatmeal Raisin
# City
# Boston        1079.10         852.72        3362.56
# Los Angeles    294.30        1421.20        1723.88
# New York      1944.56         697.51         974.12
# San Diego      904.70         809.71           0.00

# %%
sp_wheat = (df['Product'].str.contains('Chip'))

df[sp_wheat]
# Out:
#      OrderDate Region         City Category         Product  Quantity  \
# 2   2020-01-07   West  Los Angeles  Cookies  Chocolate Chip      58.0
# 3   2020-01-10   East     New York  Cookies  Chocolate Chip      82.0
# 9   2020-01-28   East     New York   Snacks    Potato Chips      28.0
# 11  2020-02-03   East       Boston  Cookies  Chocolate Chip      31.0
# 15  2020-02-15   East     New York   Snacks    Potato Chips      27.0
# 20  2020-03-02   East     New York  Cookies  Chocolate Chip      85.0
# 24  2020-03-14   West  Los Angeles  Cookies  Chocolate Chip      86.0
# 26  2020-03-20   East     New York   Snacks    Potato Chips      68.0
# 27  2020-03-23   West    San Diego  Cookies  Chocolate Chip      39.0
# 31  2020-04-04   West  Los Angeles   Snacks    Potato Chips      68.0
# 34  2020-04-13   West    San Diego   Snacks    Potato Chips      28.0
# 36  2020-04-19   East       Boston   Snacks    Potato Chips     134.0
# ...

# %%
df.columns
# Out:
# Index(['OrderDate', 'Region', 'City', 'Category', 'Product', 'Quantity',
#        'UnitPrice', 'TotalPrice'],
#       dtype='object')

# %%
sp2_test = ( ((df['Category'] == 'Cookies') | (df['Category'] == 'Snacks') ) & (df['UnitPrice'] > 3.0) )
df[sp2_test]
# Out:
#      OrderDate Region    City Category   Product  Quantity  UnitPrice  \
# 85  2020-09-13   East  Boston   Snacks  Pretzels      27.0       3.15
# 124 2021-01-08   East  Boston   Snacks  Pretzels      29.0       3.15
# 139 2021-02-22   East  Boston   Snacks  Pretzels      31.0       3.15
# 168 2021-05-19   East  Boston   Snacks  Pretzels      30.0       3.15
# 197 2021-08-14   East  Boston   Snacks  Pretzels      22.0       3.15
# 204 2021-09-04   East  Boston   Snacks  Pretzels      26.0       3.15
# 212 2021-09-28   East  Boston   Snacks  Pretzels      21.0       3.15
#
#      TotalPrice
# 85        85.05
# 124       91.35
# 139       97.65
# 168       94.50
# 197       69.30
# 204       81.90
# 212       66.15

# %%
sp2_test = ( ((df['Category'] == 'Snacks') ) & (df['UnitPrice'] > 2.0) )
df.loc[sp2_test]
# Out:
#      OrderDate Region    City Category   Product  Quantity  UnitPrice  \
# 85  2020-09-13   East  Boston   Snacks  Pretzels      27.0       3.15
# 124 2021-01-08   East  Boston   Snacks  Pretzels      29.0       3.15
# 139 2021-02-22   East  Boston   Snacks  Pretzels      31.0       3.15
# 168 2021-05-19   East  Boston   Snacks  Pretzels      30.0       3.15
# 197 2021-08-14   East  Boston   Snacks  Pretzels      22.0       3.15
# 204 2021-09-04   East  Boston   Snacks  Pretzels      26.0       3.15
# 212 2021-09-28   East  Boston   Snacks  Pretzels      21.0       3.15
#
#      TotalPrice
# 85        85.05
# 124       91.35
# 139       97.65
# 168       94.50
# 197       69.30
# 204       81.90
# 212       66.15

# %%
df.columns = [x.upper() for x in df.columns]

df.head()
# Out:
#    ORDERDATE REGION         CITY  CATEGORY         PRODUCT  QUANTITY  \
# 0 2020-01-01   East       Boston      Bars          Carrot      33.0
# 1 2020-01-04   East       Boston  Crackers     Whole Wheat      87.0
# 2 2020-01-07   West  Los Angeles   Cookies  Chocolate Chip      58.0
# 3 2020-01-10   East     New York   Cookies  Chocolate Chip      82.0
# 4 2020-01-13   East       Boston   Cookies       Arrowroot      38.0
#
#    UNITPRICE  TOTALPRICE
# 0       1.77       58.41
# 1       3.49      303.63
# 2       1.87      108.46
# 3       1.87      153.34
# 4       2.18       82.84

# %%
df.columns = [x.lower() for x in df.columns]
df
# Out:
#      orderdate region         city  category         product  quantity  \
# 0   2020-01-01   East       Boston      Bars          Carrot      33.0
# 1   2020-01-04   East       Boston  Crackers     Whole Wheat      87.0
# 2   2020-01-07   West  Los Angeles   Cookies  Chocolate Chip      58.0
# 3   2020-01-10   East     New York   Cookies  Chocolate Chip      82.0
# 4   2020-01-13   East       Boston   Cookies       Arrowroot      38.0
# ..         ...    ...          ...       ...             ...       ...
# 239 2021-12-18   East       Boston   Cookies       Arrowroot      34.0
# 240 2021-12-21   East       Boston   Cookies  Chocolate Chip     245.0
# 241 2021-12-24   East       Boston  Crackers     Whole Wheat      30.0
# 242 2021-12-27   West  Los Angeles      Bars            Bran      30.0
# 243 2021-12-30   West  Los Angeles   Cookies  Oatmeal Raisin      44.0
#
#      unitprice  totalprice
# 0         1.77       58.41
# 1         3.49      303.63
# 2         1.87      108.46
# ...

# %%
df_markup = df.copy()
df_markup
# Out:
#      orderdate region         city  category         product  quantity  \
# 0   2020-01-01   East       Boston      Bars          Carrot      33.0
# 1   2020-01-04   East       Boston  Crackers     Whole Wheat      87.0
# 2   2020-01-07   West  Los Angeles   Cookies  Chocolate Chip      58.0
# 3   2020-01-10   East     New York   Cookies  Chocolate Chip      82.0
# 4   2020-01-13   East       Boston   Cookies       Arrowroot      38.0
# ..         ...    ...          ...       ...             ...       ...
# 239 2021-12-18   East       Boston   Cookies       Arrowroot      34.0
# 240 2021-12-21   East       Boston   Cookies  Chocolate Chip     245.0
# 241 2021-12-24   East       Boston  Crackers     Whole Wheat      30.0
# 242 2021-12-27   West  Los Angeles      Bars            Bran      30.0
# 243 2021-12-30   West  Los Angeles   Cookies  Oatmeal Raisin      44.0
#
#      unitprice  totalprice
# 0         1.77       58.41
# 1         3.49      303.63
# 2         1.87      108.46
# ...

# %%
df_markup.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df_markup['shelf_price'] = np.round( ( df['unitprice'] + (df['unitprice'] * 0.33) ), decimals=2 )
df_markup.columns
df_markup['shelf_price'].round(decimals=2)
# Out:
# 0      2.35
# 1      4.64
# 2      2.49
# 3      2.49
# 4      2.90
#        ...
# 239    2.90
# 240    2.49
# 241    4.64
# 242    2.49
# 243    3.78
# Name: shelf_price, Length: 244, dtype: float64

# %%
df_markup
# Out:
#      orderdate region         city  category         product  quantity  \
# 0   2020-01-01   East       Boston      Bars          Carrot      33.0
# 1   2020-01-04   East       Boston  Crackers     Whole Wheat      87.0
# 2   2020-01-07   West  Los Angeles   Cookies  Chocolate Chip      58.0
# 3   2020-01-10   East     New York   Cookies  Chocolate Chip      82.0
# 4   2020-01-13   East       Boston   Cookies       Arrowroot      38.0
# ..         ...    ...          ...       ...             ...       ...
# 239 2021-12-18   East       Boston   Cookies       Arrowroot      34.0
# 240 2021-12-21   East       Boston   Cookies  Chocolate Chip     245.0
# 241 2021-12-24   East       Boston  Crackers     Whole Wheat      30.0
# 242 2021-12-27   West  Los Angeles      Bars            Bran      30.0
# 243 2021-12-30   West  Los Angeles   Cookies  Oatmeal Raisin      44.0
#
#      unitprice  totalprice  shelf_price
# 0         1.77       58.41         2.35
# ...

# %%
df_markup.rename(columns = {'shelf_price':'user_cost'}, inplace=True)

# %%
df_markup.head()
# Out:
#    orderdate region         city  category         product  quantity  \
# 0 2020-01-01   East       Boston      Bars          Carrot      33.0
# 1 2020-01-04   East       Boston  Crackers     Whole Wheat      87.0
# 2 2020-01-07   West  Los Angeles   Cookies  Chocolate Chip      58.0
# 3 2020-01-10   East     New York   Cookies  Chocolate Chip      82.0
# 4 2020-01-13   East       Boston   Cookies       Arrowroot      38.0
#
#    unitprice  totalprice  user_cost
# 0       1.77       58.41       2.35
# 1       3.49      303.63       4.64
# 2       1.87      108.46       2.49
# 3       1.87      153.34       2.49
# 4       2.18       82.84       2.90

# %%
df_markup.loc[3]
# Out:
# orderdate     2020-01-10 00:00:00
# region                       East
# city                     New York
# category                  Cookies
# product            Chocolate Chip
# quantity                     82.0
# unitprice                    1.87
# totalprice                 153.34
# user_cost                    2.49
# Name: 3, dtype: object

# %%
df_markup.loc[3,'user_cost'] = np.round( df_markup.loc[3,'unitprice'] * 0.43 + df_markup.loc[3,'unitprice'] , decimals=2 )

# %%
df_markup.loc[3]
# Out:
# orderdate     2020-01-10 00:00:00
# region                       East
# city                     New York
# category                  Cookies
# product            Chocolate Chip
# quantity                     82.0
# unitprice                    1.87
# totalprice                 153.34
# user_cost                    2.67
# Name: 3, dtype: object

# %%
df_markup.loc[3, ['category','region']] = ['Nuts','West']

# %%
df_markup
# Out:
#      orderdate region         city  category         product  quantity  \
# 0   2020-01-01   East       Boston      Bars          Carrot      33.0
# 1   2020-01-04   East       Boston  Crackers     Whole Wheat      87.0
# 2   2020-01-07   West  Los Angeles   Cookies  Chocolate Chip      58.0
# 3   2020-01-10   West     New York      Nuts  Chocolate Chip      82.0
# 4   2020-01-13   East       Boston   Cookies       Arrowroot      38.0
# ..         ...    ...          ...       ...             ...       ...
# 239 2021-12-18   East       Boston   Cookies       Arrowroot      34.0
# 240 2021-12-21   East       Boston   Cookies  Chocolate Chip     245.0
# 241 2021-12-24   East       Boston  Crackers     Whole Wheat      30.0
# 242 2021-12-27   West  Los Angeles      Bars            Bran      30.0
# 243 2021-12-30   West  Los Angeles   Cookies  Oatmeal Raisin      44.0
#
#      unitprice  totalprice  user_cost
# 0         1.77       58.41       2.35
# ...

# %%
df_markup.loc[3, ['category','region']] = ['Cookies','East']

# %%
df_markup
# Out:
#      orderdate region         city  category         product  quantity  \
# 0   2020-01-01   East       Boston      Bars          Carrot      33.0
# 1   2020-01-04   East       Boston  Crackers     Whole Wheat      87.0
# 2   2020-01-07   West  Los Angeles   Cookies  Chocolate Chip      58.0
# 3   2020-01-10   East     New York   Cookies  Chocolate Chip      82.0
# 4   2020-01-13   East       Boston   Cookies       Arrowroot      38.0
# ..         ...    ...          ...       ...             ...       ...
# 239 2021-12-18   East       Boston   Cookies       Arrowroot      34.0
# 240 2021-12-21   East       Boston   Cookies  Chocolate Chip     245.0
# 241 2021-12-24   East       Boston  Crackers     Whole Wheat      30.0
# 242 2021-12-27   West  Los Angeles      Bars            Bran      30.0
# 243 2021-12-30   West  Los Angeles   Cookies  Oatmeal Raisin      44.0
#
#      unitprice  totalprice  user_cost
# 0         1.77       58.41       2.35
# ...

# %%
sp3_test = ( (df['city'] == 'Boston') & (df['product'] == 'Carrot') & (df['quantity'] > 70) )
df_markup[sp3_test]
# Out:
#      orderdate region    city category product  quantity  unitprice  \
# 55  2020-06-15   East  Boston     Bars  Carrot      75.0       1.77
# 63  2020-07-09   East  Boston     Bars  Carrot     136.0       1.77
# 77  2020-08-20   East  Boston     Bars  Carrot     109.0       1.77
# 84  2020-09-10   East  Boston     Bars  Carrot     143.0       1.77
# 91  2020-10-01   East  Boston     Bars  Carrot      77.0       1.77
# 146 2021-03-14   East  Boston     Bars  Carrot      93.0       1.77
#
#      totalprice  user_cost
# 55       132.75       2.35
# 63       240.72       2.35
# 77       192.93       2.35
# 84       253.11       2.35
# 91       136.29       2.35
# 146      164.61       2.35

# %%
df_sub_markup = df_markup[sp3_test].copy()

# %%
df_sub_markup
# Out:
#      orderdate region    city category product  quantity  unitprice  \
# 55  2020-06-15   East  Boston     Bars  Carrot      75.0       1.77
# 63  2020-07-09   East  Boston     Bars  Carrot     136.0       1.77
# 77  2020-08-20   East  Boston     Bars  Carrot     109.0       1.77
# 84  2020-09-10   East  Boston     Bars  Carrot     143.0       1.77
# 91  2020-10-01   East  Boston     Bars  Carrot      77.0       1.77
# 146 2021-03-14   East  Boston     Bars  Carrot      93.0       1.77
#
#      totalprice  user_cost
# 55       132.75       2.35
# 63       240.72       2.35
# 77       192.93       2.35
# 84       253.11       2.35
# 91       136.29       2.35
# 146      164.61       2.35

# %%
df_markup.loc[sp3_test, 'unitprice'] = 1.85

# %%
df_markup[sp3_test]
# Out:
#      orderdate region    city category product  quantity  unitprice  \
# 55  2020-06-15   East  Boston     Bars  Carrot      75.0       1.85
# 63  2020-07-09   East  Boston     Bars  Carrot     136.0       1.85
# 77  2020-08-20   East  Boston     Bars  Carrot     109.0       1.85
# 84  2020-09-10   East  Boston     Bars  Carrot     143.0       1.85
# 91  2020-10-01   East  Boston     Bars  Carrot      77.0       1.85
# 146 2021-03-14   East  Boston     Bars  Carrot      93.0       1.85
#
#      totalprice  user_cost
# 55       132.75       2.35
# 63       240.72       2.35
# 77       192.93       2.35
# 84       253.11       2.35
# 91       136.29       2.35
# 146      164.61       2.35

# %%
df_sub_markup.loc[sp3_test, 'unitprice'] = 1.85

def adjust_user_cost(row_data):
  ad_quantity = row_data['quantity']
  ad_unitprice = row_data['unitprice']
  if( ad_quantity > 110):
    return np.round( ( ad_unitprice * 0.33 ) + ( ad_unitprice ), decimals= 2 )
  
  else:
    return np.round( ( ad_unitprice * 0.43 ) + ( ad_unitprice ), decimals= 2 )

# %%
df_sub_markup
# Out:
#      orderdate region    city category product  quantity  unitprice  \
# 55  2020-06-15   East  Boston     Bars  Carrot      75.0       1.85
# 63  2020-07-09   East  Boston     Bars  Carrot     136.0       1.85
# 77  2020-08-20   East  Boston     Bars  Carrot     109.0       1.85
# 84  2020-09-10   East  Boston     Bars  Carrot     143.0       1.85
# 91  2020-10-01   East  Boston     Bars  Carrot      77.0       1.85
# 146 2021-03-14   East  Boston     Bars  Carrot      93.0       1.85
#
#      totalprice  user_cost
# 55       132.75       2.35
# 63       240.72       2.35
# 77       192.93       2.35
# 84       253.11       2.35
# 91       136.29       2.35
# 146      164.61       2.35

# %%
def simple_func(the_val):
  print(the_val['product'])
  print(type(the_val))

# %%
df_sub_markup['user_cost'] = df_sub_markup.apply(axis=1, func=adjust_user_cost)

# %%
df_sub_markup
# Out:
#      orderdate region    city category product  quantity  unitprice  \
# 55  2020-06-15   East  Boston     Bars  Carrot      75.0       1.85
# 63  2020-07-09   East  Boston     Bars  Carrot     136.0       1.85
# 77  2020-08-20   East  Boston     Bars  Carrot     109.0       1.85
# 84  2020-09-10   East  Boston     Bars  Carrot     143.0       1.85
# 91  2020-10-01   East  Boston     Bars  Carrot      77.0       1.85
# 146 2021-03-14   East  Boston     Bars  Carrot      93.0       1.85
#
#      totalprice  user_cost
# 55       132.75       2.65
# 63       240.72       2.46
# 77       192.93       2.65
# 84       253.11       2.46
# 91       136.29       2.65
# 146      164.61       2.65

# %%
df_sub_markup[['quantity','unitprice']].apply(adjust_user_cost)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-b8e892bca26c> in <module>()
# ----> 1 df_sub_markup[['quantity','unitprice']].apply(adjust_user_cost)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
# ...

# %%
df_sub_markup
# Out:
#      orderdate region    city category product  quantity  unitprice  \
# 55  2020-06-15   East  Boston     Bars  Carrot      75.0       1.85
# 63  2020-07-09   East  Boston     Bars  Carrot     136.0       1.85
# 77  2020-08-20   East  Boston     Bars  Carrot     109.0       1.85
# 84  2020-09-10   East  Boston     Bars  Carrot     143.0       1.85
# 91  2020-10-01   East  Boston     Bars  Carrot      77.0       1.85
# 146 2021-03-14   East  Boston     Bars  Carrot      93.0       1.85
#
#      totalprice  user_cost
# 55       132.75       2.65
# 63       240.72       2.46
# 77       192.93       2.65
# 84       253.11       2.46
# 91       136.29       2.65
# 146      164.61       2.65

# %%
def Bulk_Buyer(row_data):
  ad_quantity = row_data['quantity']
  
  if( ad_quantity > 99 ):
    #bulk buyer
    return 'yes'
  
  else:
    return 'no'

  
def adjust_user_cost2(row_data):
  ad_quantity = row_data['quantity']
  ad_unitprice = row_data['unitprice']
  return_row = row_data
  if( ad_quantity > 120):
    new_user_cost = np.round( ( ad_unitprice * 0.43 ) + ( ad_unitprice ), decimals= 2 )
    return_row['user_cost'] = new_user_cost
    return_row['bulk_buyer'] = 'yes'
    #return pd.Series([new_user_cost, 'yes'], index=['user_cost', 'bulk_buyer'])
    return return_row
  
  else:
    new_user_cost = np.round( ( ad_unitprice * 0.53 ) + ( ad_unitprice ), decimals= 2 )
    return_row['user_cost'] = new_user_cost
    return_row['bulk_buyer'] = 'no'
    #return pd.Series([new_user_cost, 'no'], index=['user_cost', 'bulk_buyer'])
    return return_row

# %%
df_sub_markup['bulk_buyer'] = df_sub_markup.apply(axis=1, func=Bulk_Buyer)
df_sub_markup
# Out:
#      orderdate region    city category product  quantity  unitprice  \
# 55  2020-06-15   East  Boston     Bars  Carrot      75.0       1.85
# 63  2020-07-09   East  Boston     Bars  Carrot     136.0       1.85
# 77  2020-08-20   East  Boston     Bars  Carrot     109.0       1.85
# 84  2020-09-10   East  Boston     Bars  Carrot     143.0       1.85
# 91  2020-10-01   East  Boston     Bars  Carrot      77.0       1.85
# 146 2021-03-14   East  Boston     Bars  Carrot      93.0       1.85
#
#      totalprice  user_cost bulk_buyer
# 55       132.75       2.65         no
# 63       240.72       2.46        yes
# 77       192.93       2.65        yes
# 84       253.11       2.46        yes
# 91       136.29       2.65         no
# 146      164.61       2.65         no

# %%
df_me = df_sub_markup.apply(axis=1, func=adjust_user_cost2, result_type='reduce')
df_me
# Out:
#      orderdate region    city category product  quantity  unitprice  \
# 55  2020-06-15   East  Boston     Bars  Carrot      75.0       1.85
# 63  2020-07-09   East  Boston     Bars  Carrot     136.0       1.85
# 77  2020-08-20   East  Boston     Bars  Carrot     109.0       1.85
# 84  2020-09-10   East  Boston     Bars  Carrot     143.0       1.85
# 91  2020-10-01   East  Boston     Bars  Carrot      77.0       1.85
# 146 2021-03-14   East  Boston     Bars  Carrot      93.0       1.85
#
#      totalprice  user_cost bulk_buyer
# 55       132.75       2.83         no
# 63       240.72       2.65        yes
# 77       192.93       2.83         no
# 84       253.11       2.65        yes
# 91       136.29       2.83         no
# 146      164.61       2.83         no

# %%
df_markup.loc[sp3_test, ['user_cost','bulk_buyer']] = df_sub_markup.apply(axis=1, func=adjust_user_cost2)
df_markup.loc[sp3_test]
# Out:
#      orderdate region    city category product  quantity  unitprice  \
# 55  2020-06-15   East  Boston     Bars  Carrot      75.0       1.85
# 63  2020-07-09   East  Boston     Bars  Carrot     136.0       1.85
# 77  2020-08-20   East  Boston     Bars  Carrot     109.0       1.85
# 84  2020-09-10   East  Boston     Bars  Carrot     143.0       1.85
# 91  2020-10-01   East  Boston     Bars  Carrot      77.0       1.85
# 146 2021-03-14   East  Boston     Bars  Carrot      93.0       1.85
#
#      totalprice    user_cost   bulk_buyer
# 55       132.75   [2.65, no]   [2.65, no]
# 63       240.72  [2.55, yes]  [2.55, yes]
# 77       192.93   [2.65, no]   [2.65, no]
# 84       253.11  [2.55, yes]  [2.55, yes]
# 91       136.29   [2.65, no]   [2.65, no]
# 146      164.61   [2.65, no]   [2.65, no]

# %%
df_markup
# Out:
#      orderdate region         city  category         product  quantity  \
# 0   2020-01-01   East       Boston      Bars          Carrot      33.0
# 1   2020-01-04   East       Boston  Crackers     Whole Wheat      87.0
# 2   2020-01-07   West  Los Angeles   Cookies  Chocolate Chip      58.0
# 3   2020-01-10   East     New York   Cookies  Chocolate Chip      82.0
# 4   2020-01-13   East       Boston   Cookies       Arrowroot      38.0
# ..         ...    ...          ...       ...             ...       ...
# 239 2021-12-18   East       Boston   Cookies       Arrowroot      34.0
# 240 2021-12-21   East       Boston   Cookies  Chocolate Chip     245.0
# 241 2021-12-24   East       Boston  Crackers     Whole Wheat      30.0
# 242 2021-12-27   West  Los Angeles      Bars            Bran      30.0
# 243 2021-12-30   West  Los Angeles   Cookies  Oatmeal Raisin      44.0
#
#      unitprice  totalprice  user_cost
# 0         1.77       58.41       2.35
# ...

# %%
df_markup.sort_values(by='product')
# Out:
#      orderdate region         city  category      product  quantity  \
# 121 2020-12-30   West    San Diego   Cookies    Arrowroot      83.0
# 191 2021-07-27   West  Los Angeles   Cookies    Arrowroot      20.0
# 185 2021-07-09   East     New York   Cookies    Arrowroot      37.0
# 171 2021-05-28   West    San Diego   Cookies    Arrowroot      36.0
# 48  2020-05-25   East       Boston   Cookies    Arrowroot      27.0
# ..         ...    ...          ...       ...          ...       ...
# 50  2020-05-31   East       Boston  Crackers  Whole Wheat      33.0
# 56  2020-06-18   East       Boston  Crackers  Whole Wheat      38.0
# 54  2020-06-12   West    San Diego  Crackers  Whole Wheat      20.0
# 78  2020-08-23   East       Boston  Crackers  Whole Wheat      21.0
# 97  2020-10-19   East     New York  Crackers  Whole Wheat      32.0
#
#      unitprice  totalprice  user_cost
# 121       2.18      180.94       2.90
# 191       2.18       43.60       2.90
# ...

# %%
# %cd /content/drive/MyDrive/Github/

# %cd women_violence
# %ls -a
# Out:
# /content/drive/MyDrive/Github
# /content/drive/MyDrive/Github/women_violence
# violence_data.csv

# %%
df = pd.read_csv("violence_data.csv", index_col=0)

# %%
df
# Out:
#               Country Gender Demographics Question  \
# RecordID
# 1         Afghanistan      F        Marital status
# 1         Afghanistan      F             Education
# 1         Afghanistan      F             Education
# 1         Afghanistan      F             Education
# 1         Afghanistan      F        Marital status
# ...               ...    ...                   ...
# 210          Zimbabwe      M             Residence
# 280          Zimbabwe      M             Residence
# 280          Zimbabwe      M             Residence
# 350          Zimbabwe      M             Residence
# 350          Zimbabwe      M             Residence
#
#                  Demographics Response  \
# RecordID
# 1                        Never married
# 1                               Higher
# 1                            Secondary
# 1                              Primary
# 1         Widowed, divorced, separated
# ...                                ...
# 210                              Urban
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Gender', 'Demographics Question', 'Demographics Response',
#        'Question', 'Survey Year', 'Value'],
#       dtype='object')

# %%
df.pivot_table(index='Country', columns='Demographics Question', values='Value')
# Out:
# Demographics Question        Age  Education  Employment  Marital status  \
# Country
# Afghanistan            44.997222  40.316667   45.130556       40.245833
# Albania                 4.252778   6.858333    4.936111        5.761111
# Angola                 12.805556  11.970833   13.330556       13.894444
# Armenia                 8.411111   8.875000   11.588889        9.711111
# Azerbaijan             32.441667  34.280556   32.463889       31.158333
# ...                          ...        ...         ...             ...
# Uganda                 24.925000  22.200000   27.394444       26.588889
# Ukraine                 3.358333   3.420833    3.697222        4.208333
# Yemen                  29.777778  23.375000   30.450000       28.805556
# Zambia                 24.858333  21.481250   26.922222       24.980556
# Zimbabwe               17.316667  19.066667   19.108333       17.711111
#
# Demographics Question  Residence
# Country
# Afghanistan            42.712500
# ...

# %%
wf_1 = (df['Country'] == 'Afghanistan') & (df['Gender'] == 'F') & (df['Demographics Response'] == 'Rural')
df.loc[wf_1]
# Out:
#               Country Gender Demographics Question Demographics Response  \
# RecordID
# 1         Afghanistan      F             Residence                 Rural
# 351       Afghanistan      F             Residence                 Rural
# 71        Afghanistan      F             Residence                 Rural
# 141       Afghanistan      F             Residence                 Rural
# 211       Afghanistan      F             Residence                 Rural
# 281       Afghanistan      F             Residence                 Rural
#
#                                          Question Survey Year  Value
# RecordID
# 1                       ... if she burns the food  01/01/2015   18.1
# 351          ... for at least one specific reason  01/01/2015   82.1
# 71                     ... if she argues with him  01/01/2015   60.6
# 141       ... if she goes out without telling him  01/01/2015   69.3
# 211              ... if she neglects the children  01/01/2015   48.9
# ...

# %%
df.groupby('Country')['Gender'].count()
# Out:
# Country
# Afghanistan    180
# Albania        180
# Angola         180
# Armenia        180
# Azerbaijan     180
#               ...
# Uganda         180
# Ukraine        180
# Yemen          180
# Zambia         180
# Zimbabwe       180
# Name: Gender, Length: 70, dtype: int64

# %%
df.groupby('Question')['Gender'].count()
# Out:
# Question
# ... for at least one specific reason       2100
# ... if she argues with him                 2100
# ... if she burns the food                  2100
# ... if she goes out without telling him    2100
# ... if she neglects the children           2100
# ... if she refuses to have sex with him    2100
# Name: Gender, dtype: int64

# %%
wf_1 = (df['Country'] == 'Afghanistan')  & (df['Question'] == '... if she refuses to have sex with him') & (( df['Demographics Response'] == 'Rural') | (df['Demographics Response'] == 'Urban'))
df.loc[wf_1]
# Out:
#               Country Gender Demographics Question Demographics Response  \
# RecordID
# 281       Afghanistan      F             Residence                 Rural
# 281       Afghanistan      F             Residence                 Urban
# 281       Afghanistan      M             Residence                 Rural
# 281       Afghanistan      M             Residence                 Urban
#
#                                          Question Survey Year  Value
# RecordID
# 281       ... if she refuses to have sex with him  01/01/2015   35.2
# 281       ... if she refuses to have sex with him  01/01/2015   27.4
# 281       ... if she refuses to have sex with him  01/01/2015   21.9
# 281       ... if she refuses to have sex with him  01/01/2015   12.0
