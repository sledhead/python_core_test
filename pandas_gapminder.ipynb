# %%
# !pwd
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
# Out:
# /content

# %%
# !pip install gapminder
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from gapminder import gapminder

# %%
gapminder.head()
# Out:
#                             lifeExp       pop   gdpPercap
# continent country     year
# Asia      Afghanistan 1952   28.801   8425333  779.445314
#                       1957   30.332   9240934  820.853030
#                       1962   31.997  10267083  853.100710
#                       1967   34.020  11537966  836.197138
#                       1972   36.088  13079460  739.981106

# %%
gapminder.index
gapminder.set_index(['continent', 'country', 'year'], inplace=True)
gapminder.head()
# Out:
#                             lifeExp       pop   gdpPercap
# continent country     year
# Asia      Afghanistan 1952   28.801   8425333  779.445314
#                       1957   30.332   9240934  820.853030
#                       1962   31.997  10267083  853.100710
#                       1967   34.020  11537966  836.197138
#                       1972   36.088  13079460  739.981106

# %%
gapminder.index
# Out:
# MultiIndex([(  'Asia', 'Afghanistan', 1952),
#             (  'Asia', 'Afghanistan', 1957),
#             (  'Asia', 'Afghanistan', 1962),
#             (  'Asia', 'Afghanistan', 1967),
#             (  'Asia', 'Afghanistan', 1972),
#             (  'Asia', 'Afghanistan', 1977),
#             (  'Asia', 'Afghanistan', 1982),
#             (  'Asia', 'Afghanistan', 1987),
#             (  'Asia', 'Afghanistan', 1992),
#             (  'Asia', 'Afghanistan', 1997),
#             ...
#             ('Africa',    'Zimbabwe', 1962),
#             ('Africa',    'Zimbabwe', 1967),
#             ('Africa',    'Zimbabwe', 1972),
#             ('Africa',    'Zimbabwe', 1977),
#             ('Africa',    'Zimbabwe', 1982),
#             ('Africa',    'Zimbabwe', 1987),
#             ('Africa',    'Zimbabwe', 1992),
#             ('Africa',    'Zimbabwe', 1997),
#             ('Africa',    'Zimbabwe', 2002),
#             ('Africa',    'Zimbabwe', 2007)],
# ...

# %%
gapminder.loc['Africa']
# Out:
#                lifeExp       pop    gdpPercap
# country  year
# Algeria  1952   43.077   9279525  2449.008185
#          1957   45.685  10270856  3013.976023
#          1962   48.303  11000948  2550.816880
#          1967   51.407  12760499  3246.991771
#          1972   54.518  14760787  4182.663766
# ...                ...       ...          ...
# Zimbabwe 1987   62.351   9216418   706.157306
#          1992   60.377  10704340   693.420786
#          1997   46.809  11404948   792.449960
#          2002   39.989  11926563   672.038623
#          2007   43.487  12311143   469.709298
#
# [624 rows x 3 columns]

# %%
gapminder.loc[('Africa','Zimbabwe')]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   """Entry point for launching an IPython kernel.
#       lifeExp       pop   gdpPercap
# year
# 1952   48.451   3080907  406.884115
# 1957   50.469   3646340  518.764268
# 1962   52.358   4277736  527.272182
# 1967   53.995   4995432  569.795071
# 1972   55.635   5861135  799.362176
# 1977   57.674   6642107  685.587682
# 1982   60.363   7636524  788.855041
# 1987   62.351   9216418  706.157306
# 1992   60.377  10704340  693.420786
# 1997   46.809  11404948  792.449960
# 2002   39.989  11926563  672.038623
# 2007   43.487  12311143  469.709298

# %%
gapminder.loc[('Africa','Zimbabwe',1992)]
# Out:
# lifeExp      6.037700e+01
# pop          1.070434e+07
# gdpPercap    6.934208e+02
# Name: (Africa, Zimbabwe, 1992), dtype: float64

# %%
gapminder_pivot = gapminder.unstack()

# %%
gapminder_pivot
# Out:
#                          lifeExp                                          \
# year                        1952    1957    1962    1967    1972    1977
# continent country
# Africa    Algeria         43.077  45.685  48.303  51.407  54.518  58.014
#           Angola          30.015  31.999  34.000  35.985  37.928  39.483
#           Benin           38.223  40.358  42.618  44.885  47.014  49.190
#           Botswana        47.622  49.618  51.520  53.298  56.024  59.319
#           Burkina Faso    31.975  34.906  37.814  40.697  43.591  46.137
# ...                          ...     ...     ...     ...     ...     ...
# Europe    Switzerland     69.620  70.560  71.320  72.770  73.780  75.390
#           Turkey          43.585  48.079  52.098  54.336  57.005  59.507
#           United Kingdom  69.180  70.420  70.760  71.360  72.010  72.760
# Oceania   Australia       69.120  70.330  70.930  71.100  71.930  73.490
#           New Zealand     69.390  70.260  71.240  71.520  71.890  72.220
#
# ...

# %%
gapminder_unpivot = gapminder_pivot.stack()
gapminder_unpivot
# Out:
#                             lifeExp       pop     gdpPercap
# continent country     year
# Africa    Algeria     1952   43.077   9279525   2449.008185
#                       1957   45.685  10270856   3013.976023
#                       1962   48.303  11000948   2550.816880
#                       1967   51.407  12760499   3246.991771
#                       1972   54.518  14760787   4182.663766
# ...                             ...       ...           ...
# Oceania   New Zealand 1987   74.320   3317166  19007.191290
#                       1992   76.330   3437674  18363.324940
#                       1997   77.550   3676187  21050.413770
#                       2002   79.110   3908037  23189.801350
#                       2007   80.204   4115771  25185.009110
#
# [1704 rows x 3 columns]

# %%
gapminder_reset = gapminder.reset_index()
gapminder_reset
# Out:
#      continent      country  year  lifeExp       pop   gdpPercap
# 0         Asia  Afghanistan  1952   28.801   8425333  779.445314
# 1         Asia  Afghanistan  1957   30.332   9240934  820.853030
# 2         Asia  Afghanistan  1962   31.997  10267083  853.100710
# 3         Asia  Afghanistan  1967   34.020  11537966  836.197138
# 4         Asia  Afghanistan  1972   36.088  13079460  739.981106
# ...        ...          ...   ...      ...       ...         ...
# 1699    Africa     Zimbabwe  1987   62.351   9216418  706.157306
# 1700    Africa     Zimbabwe  1992   60.377  10704340  693.420786
# 1701    Africa     Zimbabwe  1997   46.809  11404948  792.449960
# 1702    Africa     Zimbabwe  2002   39.989  11926563  672.038623
# 1703    Africa     Zimbabwe  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
gapminder_reset.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
gapminder_reset.loc[4]
# Out:
# continent           Asia
# country      Afghanistan
# year                1972
# lifeExp           36.088
# pop             13079460
# gdpPercap     739.981106
# Name: 4, dtype: object

# %%
gapminder_reset.loc['Asia']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-97584d043cc6> in <module>
# ----> 1 gapminder_reset.loc['Asia']
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1162         # fall thru to straight lookup
#    1163         self._validate_key(key, axis)
# -> 1164         return self._get_label(key, axis=axis)
#    1165
#    1166     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _get_label(self, label, axis)
# ...

# %%
gapminder_reset[2:5]
# Out:
#   continent      country  year  lifeExp       pop   gdpPercap
# 2      Asia  Afghanistan  1962   31.997  10267083  853.100710
# 3      Asia  Afghanistan  1967   34.020  11537966  836.197138
# 4      Asia  Afghanistan  1972   36.088  13079460  739.981106

# %%
gapminder_reset.loc[2:6,['year','pop']]
# Out:
#    year       pop
# 2  1962  10267083
# 3  1967  11537966
# 4  1972  13079460
# 5  1977  14880372
# 6  1982  12881816

# %%
gapminder_reset
# Out:
#      continent      country  year  lifeExp       pop   gdpPercap
# 0         Asia  Afghanistan  1952   28.801   8425333  779.445314
# 1         Asia  Afghanistan  1957   30.332   9240934  820.853030
# 2         Asia  Afghanistan  1962   31.997  10267083  853.100710
# 3         Asia  Afghanistan  1967   34.020  11537966  836.197138
# 4         Asia  Afghanistan  1972   36.088  13079460  739.981106
# ...        ...          ...   ...      ...       ...         ...
# 1699    Africa     Zimbabwe  1987   62.351   9216418  706.157306
# 1700    Africa     Zimbabwe  1992   60.377  10704340  693.420786
# 1701    Africa     Zimbabwe  1997   46.809  11404948  792.449960
# 1702    Africa     Zimbabwe  2002   39.989  11926563  672.038623
# 1703    Africa     Zimbabwe  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
gapminder_reset.loc[gapminder_reset['year'] == 1992]
# Out:
#      continent             country  year  lifeExp       pop    gdpPercap
# 8         Asia         Afghanistan  1992   41.674  16317921   649.341395
# 20      Europe             Albania  1992   71.581   3326498  2497.437901
# 32      Africa             Algeria  1992   67.744  26298373  5023.216647
# 44      Africa              Angola  1992   40.647   8735988  2627.845685
# 56    Americas           Argentina  1992   71.868  33958947  9308.418710
# ...        ...                 ...   ...      ...       ...          ...
# 1652      Asia             Vietnam  1992   67.662  69940728   989.023149
# 1664      Asia  West Bank and Gaza  1992   69.718   2104779  6017.654756
# 1676      Asia         Yemen, Rep.  1992   55.599  13367997  1879.496673
# 1688    Africa              Zambia  1992   46.100   8381163  1210.884633
# 1700    Africa            Zimbabwe  1992   60.377  10704340   693.420786
#
# [142 rows x 6 columns]

# %%
gapminder_reset.loc[(gapminder_reset['pop'] > 2104780) & (gapminder_reset['year'] == 1992)]
# Out:
#      continent      country  year  lifeExp       pop     gdpPercap
# 8         Asia  Afghanistan  1992   41.674  16317921    649.341395
# 20      Europe      Albania  1992   71.581   3326498   2497.437901
# 32      Africa      Algeria  1992   67.744  26298373   5023.216647
# 44      Africa       Angola  1992   40.647   8735988   2627.845685
# 56    Americas    Argentina  1992   71.868  33958947   9308.418710
# ...        ...          ...   ...      ...       ...           ...
# 1640  Americas    Venezuela  1992   71.150  20265563  10733.926310
# 1652      Asia      Vietnam  1992   67.662  69940728    989.023149
# 1676      Asia  Yemen, Rep.  1992   55.599  13367997   1879.496673
# 1688    Africa       Zambia  1992   46.100   8381163   1210.884633
# 1700    Africa     Zimbabwe  1992   60.377  10704340    693.420786
#
# [120 rows x 6 columns]

# %%
gapminder_reset
# Out:
#      continent      country  year  lifeExp       pop   gdpPercap
# 0         Asia  Afghanistan  1952   28.801   8425333  779.445314
# 1         Asia  Afghanistan  1957   30.332   9240934  820.853030
# 2         Asia  Afghanistan  1962   31.997  10267083  853.100710
# 3         Asia  Afghanistan  1967   34.020  11537966  836.197138
# 4         Asia  Afghanistan  1972   36.088  13079460  739.981106
# ...        ...          ...   ...      ...       ...         ...
# 1699    Africa     Zimbabwe  1987   62.351   9216418  706.157306
# 1700    Africa     Zimbabwe  1992   60.377  10704340  693.420786
# 1701    Africa     Zimbabwe  1997   46.809  11404948  792.449960
# 1702    Africa     Zimbabwe  2002   39.989  11926563  672.038623
# 1703    Africa     Zimbabwe  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
gg = gapminder_reset.groupby(['continent','country','year'])['pop'].mean()

# %%
gg.index
# Out:
# MultiIndex([( 'Africa',     'Algeria', 1952),
#             ( 'Africa',     'Algeria', 1957),
#             ( 'Africa',     'Algeria', 1962),
#             ( 'Africa',     'Algeria', 1967),
#             ( 'Africa',     'Algeria', 1972),
#             ( 'Africa',     'Algeria', 1977),
#             ( 'Africa',     'Algeria', 1982),
#             ( 'Africa',     'Algeria', 1987),
#             ( 'Africa',     'Algeria', 1992),
#             ( 'Africa',     'Algeria', 1997),
#             ...
#             ('Oceania', 'New Zealand', 1962),
#             ('Oceania', 'New Zealand', 1967),
#             ('Oceania', 'New Zealand', 1972),
#             ('Oceania', 'New Zealand', 1977),
#             ('Oceania', 'New Zealand', 1982),
#             ('Oceania', 'New Zealand', 1987),
#             ('Oceania', 'New Zealand', 1992),
#             ('Oceania', 'New Zealand', 1997),
#             ('Oceania', 'New Zealand', 2002),
#             ('Oceania', 'New Zealand', 2007)],
# ...

# %%
gg.loc[:,'New Zealand',:]
# Out:
# continent  year
# Oceania    1952    1994794.0
#            1957    2229407.0
#            1962    2488550.0
#            1967    2728150.0
#            1972    2929100.0
#            1977    3164900.0
#            1982    3210650.0
#            1987    3317166.0
#            1992    3437674.0
#            1997    3676187.0
#            2002    3908037.0
#            2007    4115771.0
# Name: pop, dtype: float64

# %%
gapminder.index
# Out:
# MultiIndex([(  'Asia', 'Afghanistan', 1952),
#             (  'Asia', 'Afghanistan', 1957),
#             (  'Asia', 'Afghanistan', 1962),
#             (  'Asia', 'Afghanistan', 1967),
#             (  'Asia', 'Afghanistan', 1972),
#             (  'Asia', 'Afghanistan', 1977),
#             (  'Asia', 'Afghanistan', 1982),
#             (  'Asia', 'Afghanistan', 1987),
#             (  'Asia', 'Afghanistan', 1992),
#             (  'Asia', 'Afghanistan', 1997),
#             ...
#             ('Africa',    'Zimbabwe', 1962),
#             ('Africa',    'Zimbabwe', 1967),
#             ('Africa',    'Zimbabwe', 1972),
#             ('Africa',    'Zimbabwe', 1977),
#             ('Africa',    'Zimbabwe', 1982),
#             ('Africa',    'Zimbabwe', 1987),
#             ('Africa',    'Zimbabwe', 1992),
#             ('Africa',    'Zimbabwe', 1997),
#             ('Africa',    'Zimbabwe', 2002),
#             ('Africa',    'Zimbabwe', 2007)],
# ...

# %%
gapminder.loc[:,'Zimbabwe',:]
# Out:
#                          lifeExp       pop   gdpPercap
# continent country  year
# Africa    Zimbabwe 1952   48.451   3080907  406.884115
#                    1957   50.469   3646340  518.764268
#                    1962   52.358   4277736  527.272182
#                    1967   53.995   4995432  569.795071
#                    1972   55.635   5861135  799.362176
#                    1977   57.674   6642107  685.587682
#                    1982   60.363   7636524  788.855041
#                    1987   62.351   9216418  706.157306
#                    1992   60.377  10704340  693.420786
#                    1997   46.809  11404948  792.449960
#                    2002   39.989  11926563  672.038623
#                    2007   43.487  12311143  469.709298

# %%
gapminder
# Out:
#                             lifeExp       pop   gdpPercap
# continent country     year
# Asia      Afghanistan 1952   28.801   8425333  779.445314
#                       1957   30.332   9240934  820.853030
#                       1962   31.997  10267083  853.100710
#                       1967   34.020  11537966  836.197138
#                       1972   36.088  13079460  739.981106
# ...                             ...       ...         ...
# Africa    Zimbabwe    1987   62.351   9216418  706.157306
#                       1992   60.377  10704340  693.420786
#                       1997   46.809  11404948  792.449960
#                       2002   39.989  11926563  672.038623
#                       2007   43.487  12311143  469.709298
#
# [1704 rows x 3 columns]

# %%
gapminder['pop']
# Out:
# continent  country      year
# Asia       Afghanistan  1952     8425333
#                         1957     9240934
#                         1962    10267083
#                         1967    11537966
#                         1972    13079460
#                                   ...
# Africa     Zimbabwe     1987     9216418
#                         1992    10704340
#                         1997    11404948
#                         2002    11926563
#                         2007    12311143
# Name: pop, Length: 1704, dtype: int64

# %%
gapminder.loc[:, 'pop']
# Out:
# continent  country      year
# Asia       Afghanistan  1952     8425333
#                         1957     9240934
#                         1962    10267083
#                         1967    11537966
#                         1972    13079460
#                                   ...
# Africa     Zimbabwe     1987     9216418
#                         1992    10704340
#                         1997    11404948
#                         2002    11926563
#                         2007    12311143
# Name: pop, Length: 1704, dtype: int64

# %%
gapminder_reset
# Out:
#      continent      country  year  lifeExp       pop   gdpPercap
# 0         Asia  Afghanistan  1952   28.801   8425333  779.445314
# 1         Asia  Afghanistan  1957   30.332   9240934  820.853030
# 2         Asia  Afghanistan  1962   31.997  10267083  853.100710
# 3         Asia  Afghanistan  1967   34.020  11537966  836.197138
# 4         Asia  Afghanistan  1972   36.088  13079460  739.981106
# ...        ...          ...   ...      ...       ...         ...
# 1699    Africa     Zimbabwe  1987   62.351   9216418  706.157306
# 1700    Africa     Zimbabwe  1992   60.377  10704340  693.420786
# 1701    Africa     Zimbabwe  1997   46.809  11404948  792.449960
# 1702    Africa     Zimbabwe  2002   39.989  11926563  672.038623
# 1703    Africa     Zimbabwe  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
gapminder_reset.loc[:,'continent':'year']
# Out:
#      continent      country  year
# 0         Asia  Afghanistan  1952
# 1         Asia  Afghanistan  1957
# 2         Asia  Afghanistan  1962
# 3         Asia  Afghanistan  1967
# 4         Asia  Afghanistan  1972
# ...        ...          ...   ...
# 1699    Africa     Zimbabwe  1987
# 1700    Africa     Zimbabwe  1992
# 1701    Africa     Zimbabwe  1997
# 1702    Africa     Zimbabwe  2002
# 1703    Africa     Zimbabwe  2007
#
# [1704 rows x 3 columns]

# %%
gapminder_reset.loc[gapminder_reset['continent'] == 'Asia']
# Out:
#      continent      country  year  lifeExp       pop    gdpPercap
# 0         Asia  Afghanistan  1952   28.801   8425333   779.445314
# 1         Asia  Afghanistan  1957   30.332   9240934   820.853030
# 2         Asia  Afghanistan  1962   31.997  10267083   853.100710
# 3         Asia  Afghanistan  1967   34.020  11537966   836.197138
# 4         Asia  Afghanistan  1972   36.088  13079460   739.981106
# ...        ...          ...   ...      ...       ...          ...
# 1675      Asia  Yemen, Rep.  1987   52.922  11219340  1971.741538
# 1676      Asia  Yemen, Rep.  1992   55.599  13367997  1879.496673
# 1677      Asia  Yemen, Rep.  1997   58.020  15826497  2117.484526
# 1678      Asia  Yemen, Rep.  2002   60.308  18701257  2234.820827
# 1679      Asia  Yemen, Rep.  2007   62.698  22211743  2280.769906
#
# [396 rows x 6 columns]

# %%
gapminder
# Out:
#                             lifeExp       pop   gdpPercap
# continent country     year
# Asia      Afghanistan 1952   28.801   8425333  779.445314
#                       1957   30.332   9240934  820.853030
#                       1962   31.997  10267083  853.100710
#                       1967   34.020  11537966  836.197138
#                       1972   36.088  13079460  739.981106
# ...                             ...       ...         ...
# Africa    Zimbabwe    1987   62.351   9216418  706.157306
#                       1992   60.377  10704340  693.420786
#                       1997   46.809  11404948  792.449960
#                       2002   39.989  11926563  672.038623
#                       2007   43.487  12311143  469.709298
#
# [1704 rows x 3 columns]

# %%
gapminder.loc['Asia','Afghanistan',[1952,1967,1972]]
# Out:
#                             lifeExp       pop   gdpPercap
# continent country     year
# Asia      Afghanistan 1952   28.801   8425333  779.445314
#                       1967   34.020  11537966  836.197138
#                       1972   36.088  13079460  739.981106

# %%
gapminder.loc['Africa','Algeria',:]
# Out:
#                         lifeExp       pop    gdpPercap
# continent country year
# Africa    Algeria 1952   43.077   9279525  2449.008185
#                   1957   45.685  10270856  3013.976023
#                   1962   48.303  11000948  2550.816880
#                   1967   51.407  12760499  3246.991771
#                   1972   54.518  14760787  4182.663766
#                   1977   58.014  17152804  4910.416756
#                   1982   61.368  20033753  5745.160213
#                   1987   65.799  23254956  5681.358539
#                   1992   67.744  26298373  5023.216647
#                   1997   69.152  29072015  4797.295051
#                   2002   70.994  31287142  5288.040382
#                   2007   72.301  33333216  6223.367465

# %%
rr = gapminder.groupby(['continent','country'])['pop'].count()

# %%
rr.index
# Out:
# MultiIndex([( 'Africa',                  'Algeria'),
#             ( 'Africa',                   'Angola'),
#             ( 'Africa',                    'Benin'),
#             ( 'Africa',                 'Botswana'),
#             ( 'Africa',             'Burkina Faso'),
#             ( 'Africa',                  'Burundi'),
#             ( 'Africa',                 'Cameroon'),
#             ( 'Africa', 'Central African Republic'),
#             ( 'Africa',                     'Chad'),
#             ( 'Africa',                  'Comoros'),
#             ...
#             ( 'Europe',                   'Serbia'),
#             ( 'Europe',          'Slovak Republic'),
#             ( 'Europe',                 'Slovenia'),
#             ( 'Europe',                    'Spain'),
#             ( 'Europe',                   'Sweden'),
#             ( 'Europe',              'Switzerland'),
#             ( 'Europe',                   'Turkey'),
# ...

# %%
rr.loc['Africa',:]
# Out:
# continent  country
# Africa     Algeria                     12
#            Angola                      12
#            Benin                       12
#            Botswana                    12
#            Burkina Faso                12
#            Burundi                     12
#            Cameroon                    12
#            Central African Republic    12
#            Chad                        12
#            Comoros                     12
#            Congo, Dem. Rep.            12
#            Congo, Rep.                 12
#            Cote d'Ivoire               12
#            Djibouti                    12
#            Egypt                       12
#            Equatorial Guinea           12
#            Eritrea                     12
#            Ethiopia                    12
#            Gabon                       12
#            Gambia                      12
#            Ghana                       12
#            Guinea                      12
# ...

# %%
rr.loc['Africa','Gabon':'Liyba']
# Out:
# continent  country
# Africa     Gabon            12
#            Gambia           12
#            Ghana            12
#            Guinea           12
#            Guinea-Bissau    12
#            Kenya            12
#            Lesotho          12
#            Liberia          12
#            Libya            12
# Name: pop, dtype: int64

# %%
gapminder.loc['Africa',['Gabon','Libya'],:]
# Out:
#                         lifeExp      pop     gdpPercap
# continent country year
# Africa    Gabon   1952   37.003   420702   4293.476475
#                   1957   38.999   434904   4976.198099
#                   1962   40.489   455661   6631.459222
#                   1967   44.598   489004   8358.761987
#                   1972   48.690   537977  11401.948410
#                   1977   52.790   706367  21745.573280
#                   1982   56.564   753874  15113.361940
#                   1987   60.190   880397  11864.408440
#                   1992   61.366   985739  13522.157520
#                   1997   60.461  1126189  14722.841880
#                   2002   56.761  1299304  12521.713920
#                   2007   56.735  1454867  13206.484520
#           Libya   1952   42.723  1019729   2387.548060
#                   1957   45.289  1201578   3448.284395
#                   1962   47.808  1441863   6757.030816
#                   1967   50.227  1759224  18772.751690
# ...

# %%
gapminder
# Out:
#                             lifeExp       pop   gdpPercap
# continent country     year
# Asia      Afghanistan 1952   28.801   8425333  779.445314
#                       1957   30.332   9240934  820.853030
#                       1962   31.997  10267083  853.100710
#                       1967   34.020  11537966  836.197138
#                       1972   36.088  13079460  739.981106
# ...                             ...       ...         ...
# Africa    Zimbabwe    1987   62.351   9216418  706.157306
#                       1992   60.377  10704340  693.420786
#                       1997   46.809  11404948  792.449960
#                       2002   39.989  11926563  672.038623
#                       2007   43.487  12311143  469.709298
#
# [1704 rows x 3 columns]

# %%
gapminder.loc['Africa','Gabon',:]
# Out:
#                         lifeExp      pop     gdpPercap
# continent country year
# Africa    Gabon   1952   37.003   420702   4293.476475
#                   1957   38.999   434904   4976.198099
#                   1962   40.489   455661   6631.459222
#                   1967   44.598   489004   8358.761987
#                   1972   48.690   537977  11401.948410
#                   1977   52.790   706367  21745.573280
#                   1982   56.564   753874  15113.361940
#                   1987   60.190   880397  11864.408440
#                   1992   61.366   985739  13522.157520
#                   1997   60.461  1126189  14722.841880
#                   2002   56.761  1299304  12521.713920
#                   2007   56.735  1454867  13206.484520

# %%
gapminder.loc[('Africa','Gabon',[1957,1962]), :]
# Out:
#                         lifeExp     pop    gdpPercap
# continent country year
# Africa    Gabon   1957   38.999  434904  4976.198099
#                   1962   40.489  455661  6631.459222

# %%
gapminder.loc[('Africa','Gabon',1962), :]
# Out:
# lifeExp          40.489000
# pop          455661.000000
# gdpPercap      6631.459222
# Name: (Africa, Gabon, 1962), dtype: float64

# %%
gapminder_reset.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
gapminder_reset.loc[gapminder_reset['year'] == 1967]
# Out:
#      continent             country  year  lifeExp       pop    gdpPercap
# 3         Asia         Afghanistan  1967   34.020  11537966   836.197138
# 15      Europe             Albania  1967   66.220   1984060  2760.196931
# 27      Africa             Algeria  1967   51.407  12760499  3246.991771
# 39      Africa              Angola  1967   35.985   5247469  5522.776375
# 51    Americas           Argentina  1967   65.634  22934225  8052.953021
# ...        ...                 ...   ...      ...       ...          ...
# 1647      Asia             Vietnam  1967   47.838  39463910   637.123289
# 1659      Asia  West Bank and Gaza  1967   51.631   1142636  2649.715007
# 1671      Asia         Yemen, Rep.  1967   36.984   6740785   862.442146
# 1683    Africa              Zambia  1967   47.768   3900000  1777.077318
# 1695    Africa            Zimbabwe  1967   53.995   4995432   569.795071
#
# [142 rows x 6 columns]

# %%
gapminder.loc['Africa','Gabon':'Libya',:]
# Out:
# ---------------------------------------------------------------------------
# UnsortedIndexError                        Traceback (most recent call last)
# <ipython-input-50-6eebf4615546> in <module>
# ----> 1 gapminder.loc['Africa','Gabon':'Libya',:]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1098     def _getitem_tuple(self, tup: tuple):
#    1099         with suppress(IndexingError):
# -> 1100             return self._getitem_lowerdim(tup)
#    1101
#    1102         # no multi-index, so validate all of the indexers
#
# ...
