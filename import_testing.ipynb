# %%
# %%writefile simple_import.py

import os

base_folder_path = os.getcwd()

complete_path = os.path.join(base_folder_path,'mini','farm')


def say_hello():
  for i in range(1,5):
    print(f'hello this many times: {i}')

def show_complete_path():
  print(complete_path)
  return complete_path
# Out:
# Overwriting simple_import.py

# %%
import os
from simple_import import say_hello,show_complete_path

# %%
say_hello()

show_complete_path()

farm_txt = show_complete_path()

print(farm_txt)
# Out:
# hello this many times: 1
# hello this many times: 2
# hello this many times: 3
# hello this many times: 4
# /content/mini/farm
# /content/mini/farm
# /content/mini/farm

# %%
os.getcwd()
print(farm_txt + '.txt')

new_folder_path = os.path.join(os.getcwd(), 'New', 'cookout.txt')
print(new_folder_path)
# Out:
# /content/mini/farm.txt
# /content/New/cookout.txt
