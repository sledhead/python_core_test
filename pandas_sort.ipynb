# %%
import pandas as pd
import numpy as np

# %%
# !wget https://github.com/selva86/datasets/raw/master/supermarket_sales.csv
# Out:
# --2022-10-13 08:45:19--  https://github.com/selva86/datasets/raw/master/supermarket_sales.csv
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/selva86/datasets/master/supermarket_sales.csv [following]
# --2022-10-13 08:45:20--  https://raw.githubusercontent.com/selva86/datasets/master/supermarket_sales.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 131528 (128K) [text/plain]
# Saving to: ‘supermarket_sales.csv’
#
# supermarket_sales.c 100%[===================>] 128.45K  --.-KB/s    in 0.01s
#
# 2022-10-13 08:45:20 (8.65 MB/s) - ‘supermarket_sales.csv’ saved [131528/131528]

# %%
df = pd.read_csv('supermarket_sales.csv')
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df_sort = df.sort_values('Branch')
df_sort
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 530  287-83-1405      A     Yangon        Normal    Male
# 529  827-77-7633      A     Yangon        Normal    Male
# 525  719-89-8991      A     Yangon        Member  Female
# 524  534-01-4457      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 299  779-06-0012      C  Naypyitaw        Member  Female
# 613  284-54-4231      C  Naypyitaw        Member    Male
# 611  277-35-5865      C  Naypyitaw        Member  Female
# 641  155-45-3814      C  Naypyitaw        Member  Female
# 663  641-51-2661      C  Naypyitaw        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 0         Health and beauty       74.69         7  26.1415  548.9715
# 530       Health and beauty       25.43         6   7.6290  160.2090
# 529       Sports and travel       98.09         9  44.1405  926.9505
# ...

# %%
df_sort = df.sort_values(['Branch', 'Payment'])
df_sort
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 14   829-34-3910      A     Yangon        Normal  Female
# 29   848-62-7243      A     Yangon        Normal    Male
# 51   162-48-8011      A     Yangon        Member  Female
# 56   106-35-6779      A     Yangon        Member    Male
# 58   817-48-8732      A     Yangon        Member  Female
# ..           ...    ...        ...           ...     ...
# 939  500-02-2261      C  Naypyitaw        Normal  Female
# 948  373-88-1424      C  Naypyitaw        Member    Male
# 988  267-62-7380      C  Naypyitaw        Member    Male
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 995  233-67-5758      C  Naypyitaw        Normal    Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 14        Health and beauty       71.38        10  35.6900  749.4900
# 29        Health and beauty       24.89         9  11.2005  235.2105
# 51       Food and beverages       44.59         5  11.1475  234.0975
# ...
